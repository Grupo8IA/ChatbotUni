# %% [markdown]
# # Carga y preprocesamiento de la Data

# %% [markdown]
# En este preprocesamiento de dato se usaron 2 tipos de dataset que originalmente estaba en ingles pero se traducieron al españo (https://github.com/CHANEL-JSALT-2020/datasets) :
#  1. DAILYD.csv : Un conjunto de datos de diálogo de múltiples.
#  2. METALW.csv : Un conjunto de datos de diálogos multidominio para la rápida adaptacion de modelos de conversación

# %% [markdown]
# ## Importaciones

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import argparse
import codecs
import csv
import os
import re

# %%
## Muestra las 8 primeras filas de un archivo csv
def mostrarLinea(archivo, n=8):
    with open(archivo, 'r') as archivoData:
        lineas = archivoData.readlines()
    for linea in lineas[:n]:
        print(linea)
        
## se crea un diccionario donde cada llave (idDialogo) contiene un dialogo entre dos personas
def cargarLinea(data, campos):
    conversaciones = {}
    with open(data, 'r') as archivoCsv:
        
        linea = csv.reader(archivoCsv, delimiter = ',')
        next(linea)        
        for row in linea:
            lineObj = {}
            for i , campo in enumerate(campos):
                # En el dataset la palabra "ufeffUID" identifica en que parte de la
                # conversación de un dialogo se encuentra
                if("ufeffUID" in campo):
                    aux = row[i].split("-")
                    lineObj["idDialogo"] = aux[1]
                else:
                    lineObj[campo] = row[i]
            
            # Cada linea es un dialogo donde se separa por '\t'
            if(lineObj["idDialogo"] in conversaciones):
                conversaciones[lineObj["idDialogo"]] += '\t'+ lineObj["text"]
            else:
                conversaciones[lineObj["idDialogo"]] = lineObj["text"]
                
    return conversaciones

# Separacion en pares de cada dialogo
def pares(conversaciones):
    pares = []
    
    for i in conversaciones:
        
        linea = conversaciones[i].split('\t')
        
        if len(linea) != 1:
            
            for i in range((len(linea)  + 1)//  2):
                entrada = linea[i]
                salida = linea[i+1]

                if entrada and salida:
                    pares.append([entrada, salida])
    return pares

# %% [markdown]
# ## Una visualizacion del dataset Metalw

# %%
archivo = "METALW_translation_es2en_000.csv"
mostrarLinea(os.path.join("./DAILYD_METALW", archivo))
# Out:
# ﻿UID,SEG,translation,profanity
#
# METALW-000000-0000,"Hola, ¿en qué puedo ayudarle?","Hi, how can I help you?",None
#
# METALW-000000-0001,Sí,Yes,None
#
# METALW-000000-0002,¿Cómo puedo ser de ayuda?,How can I be of help?,None
#
# METALW-000000-0003,Quiero saber sobre la política que tengo,I want to know about the policy I have,None
#
# METALW-000000-0004,"Bien, ¿puedo conseguir tu nombre, por favor?","Well, can I get your name, please?",None
#
# METALW-000000-0005,¿Cubre los daños causados por el agua?,Does it cover water damage?,None
#
# METALW-000000-0006,"Necesito su nombre y número de póliza para acceder a su póliza, por favor.","I need your name and policy number to access your policy, please.",None

# %% [markdown]
# ## Extracción del dataset Metalw en pares

# %%
campos = ["ufeffUID", "text"]
campos_conversaciones = ['idDialogo', 'idConversacion', 'text']

## nombre base del dataset METALW
metalw_base = "METALW_translation_es2en_0"
pares_conversaciones = []
for i in range(44):
    
    if i < 10:
        archivo = f'{metalw_base}0{i}.csv'
        data = os.path.join("./DAILYD_METALW", archivo)
    else:
        archivo = f'{metalw_base}{i}.csv'
        data = os.path.join("./DAILYD_METALW", archivo)
        
    conversaciones = cargarLinea(data, campos)
    pares_conversaciones += pares(conversaciones)

# %%
pares_conversaciones
# Out:
# [['Hola, ¿en qué puedo ayudarle?', 'Sí'],
#  ['Sí', '¿Cómo puedo ser de ayuda?'],
#  ['¿Cómo puedo ser de ayuda?', 'Quiero saber sobre la política que tengo'],
#  ['Quiero saber sobre la política que tengo',
#   'Bien, ¿puedo conseguir tu nombre, por favor?'],
#  ['Bien, ¿puedo conseguir tu nombre, por favor?',
#   '¿Cubre los daños causados por el agua?'],
#  ['¿Cubre los daños causados por el agua?',
#   'Necesito su nombre y número de póliza para acceder a su póliza, por favor.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi política'],
#  ['Tengo una pregunta sobre mi política',
#   'seguro. ¿Puedes decirme tu número de póliza?'],
#  ['seguro. ¿Puedes decirme tu número de póliza?', '3425512'],
#  ['3425512', 'Bien, tengo tu póliza aquí. ¿Cuál es tu pregunta?'],
#  ['Bien, tengo tu póliza aquí. ¿Cuál es tu pregunta?',
#   'cubre los daños causados por el agua?'],
#  ['cubre los daños causados por el agua?',
#   'Esta política no cubre los daños causados por el agua.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Hola'],
#  ['Hola', 'hola'],
#  ['hola', 'Me gustaría tener algunas consultas'],
#  ['Me gustaría tener algunas consultas', '¿en qué puedo ayudarle? De acuerdo'],
#  ['¿en qué puedo ayudarle? De acuerdo',
#   'así que estoy tratando de comprobar con respecto a mi seguro'],
#  ['así que estoy tratando de comprobar con respecto a mi seguro',
#   'la política actual cubre los daños causados por el agua, el fuego y los actos de Dios?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'hola. Necesito ayuda con mi seguro'],
#  ['hola. Necesito ayuda con mi seguro',
#   'Claro, ¿cuál es tu número de póliza?'],
#  ['Claro, ¿cuál es tu número de póliza?', '5642394'],
#  ['5642394', 'Está bien, se ha detenido. ¿Qué puedo responder por usted?'],
#  ['Está bien, se ha detenido. ¿Qué puedo responder por usted?',
#   '¿Cómo cambio los términos de mi póliza de seguro de vida?'],
#  ['¿Cómo cambio los términos de mi póliza de seguro de vida?',
#   'Puedo cambiarlos por ti. ¿Qué te gustaría cambiar? A menos que sea información más detallada, entonces usted tendrá que hacer una cita con su corredor de seguros'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Me gustaría encontrar información sobre mi seguro.'],
#  ['Me gustaría encontrar información sobre mi seguro.',
#   'Me gustaría ayudarle con ese plan de seguro al que se refiere?'],
#  ['Me gustaría ayudarle con ese plan de seguro al que se refiere?',
#   'Mi plan de seguro de vida.'],
#  ['Mi plan de seguro de vida.',
#   '¿Me permites el número de póliza, por favor?'],
#  ['¿Me permites el número de póliza, por favor?', '2387782786'],
#  ['2387782786', 'Gracias. ¿Qué información puedo ofrecerle?'],
#  ['Gracias. ¿Qué información puedo ofrecerle?', '¿Cuánto estoy asegurado?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi política'],
#  ['Tengo una pregunta sobre mi política', '¿Qué es?'],
#  ['¿Qué es?', '¿Mi póliza cubre los daños causados por el agua?'],
#  ['¿Mi póliza cubre los daños causados por el agua?',
#   'por favor, espere mientras reviso su cobertura de daños por agua'],
#  ['por favor, espere mientras reviso su cobertura de daños por agua',
#   '¿Necesita mi número de póliza?'],
#  ['¿Necesita mi número de póliza?',
#   'al comprobar, cubre a su dama de agua en nuestra política'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puedes responder a una pregunta de seguro por mí?'],
#  ['¿Puedes responder a una pregunta de seguro por mí?',
#   'Sí, puedo. ¿Qué quieres saber?'],
#  ['Sí, puedo. ¿Qué quieres saber?',
#   '¿Me gustaría saber si la póliza de seguro típica del propietario cubre los daños causados por tornados?'],
#  ['¿Me gustaría saber si la póliza de seguro típica del propietario cubre los daños causados por tornados?',
#   'Sí, lo hace.'],
#  ['Sí, lo hace.',
#   '¿También cubre normalmente los daños causados por las inundaciones?'],
#  ['¿También cubre normalmente los daños causados por las inundaciones?',
#   'Sí, así como otros desastres naturales de naturaleza similar.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito información sobre mi seguro de propietarios'],
#  ['Necesito información sobre mi seguro de propietarios',
#   'Claro, ¿puedo obtener tu número de póliza, por favor?'],
#  ['Claro, ¿puedo obtener tu número de póliza, por favor?', '789406'],
#  ['789406', 'Está bien, tengo eso aquí. ¿Qué información necesitabas?'],
#  ['Está bien, tengo eso aquí. ¿Qué información necesitabas?',
#   '¿Cuál es mi deducción?'],
#  ['¿Cuál es mi deducción?',
#   'El deducible de su seguro de hogar es de 10,000$'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Puedes ayudarme con mi seguro?'],
#  ['¿Puedes ayudarme con mi seguro?', 'Claro. ¿Qué puedo hacer por ti hoy?'],
#  ['Claro. ¿Qué puedo hacer por ti hoy?',
#   'Quiero comprobar y ver cuál es mi deducible actual para mi seguro de automóvil'],
#  ['Quiero comprobar y ver cuál es mi deducible actual para mi seguro de automóvil',
#   '¿Puedo tener su número de póliza?'],
#  ['¿Puedo tener su número de póliza?',
#   'Claro, el número de póliza es 57348175834'],
#  ['Claro, el número de póliza es 57348175834', 'Tienes un deducible de $500.'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Puedes ayudar?'],
#  ['¿Puedes ayudar?', 'Sí, ¿qué es lo que necesitas?'],
#  ['Sí, ¿qué es lo que necesitas?', 'Necesito información sobre mi póliza.'],
#  ['Necesito información sobre mi póliza.',
#   'Claro que puedo ayudarte con eso sólo dame tu número de póliza'],
#  ['Claro que puedo ayudarte con eso sólo dame tu número de póliza',
#   '¿Dónde puedo encontrar eso?'],
#  ['¿Dónde puedo encontrar eso?', 'Debería estar en tu cuenta'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Hola'],
#  ['Hola', '¿cómo puedo ayudar?'],
#  ['¿cómo puedo ayudar?', 'compañía de seguros me ayudan'],
#  ['compañía de seguros me ayudan', 'qué seguro quieres'],
#  ['qué seguro quieres', '¿Cubre el agua? eh'],
#  ['¿Cubre el agua? eh',
#   'lo siento, pero triste decir que no cubra los daños causados por el agua'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'hola necesita saber algo acerca de mi póliza de seguro'],
#  ['hola necesita saber algo acerca de mi póliza de seguro',
#   '¿Seguro qué necesitas saber? Me encantaría ayudar.'],
#  ['¿Seguro qué necesitas saber? Me encantaría ayudar.',
#   '¿Mi póliza cubre los daños causados por el agua?'],
#  ['¿Mi póliza cubre los daños causados por el agua?',
#   'Desafortunadamente, no lo hace.'],
#  ['Desafortunadamente, no lo hace.',
#   'ok, ¿qué pasa con los daños causados por el fuego?'],
#  ['ok, ¿qué pasa con los daños causados por el fuego?',
#   'Sí. Los daños causados por el fuego están cubiertos'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi política.'],
#  ['Tengo una pregunta sobre mi política.',
#   'Claro, ¿qué le gustaría saber sobre su política?'],
#  ['Claro, ¿qué le gustaría saber sobre su política?',
#   '¿Cubre los daños causados por el agua?'],
#  ['¿Cubre los daños causados por el agua?',
#   'Déjame echar un vistazo. Aquí dice que su póliza no cubre los daños causados por el agua.'],
#  ['Déjame echar un vistazo. Aquí dice que su póliza no cubre los daños causados por el agua.',
#   '¿Puedo agregarlo a mi póliza?'],
#  ['¿Puedo agregarlo a mi póliza?',
#   'Puede hacerlo, pero debe tener en cuenta que cualquier reclamación de seguro en condiciones de "daños causados por el agua" no estará cubierta si los daños causados por el agua ocurrieron antes de actualizar su póliza.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'ayúdame con el seguro'],
#  ['ayúdame con el seguro',
#   'De acuerdo. ¿qué política está preguntando acerca de'],
#  ['De acuerdo. ¿qué política está preguntando acerca de',
#   'para mi seguro de barco'],
#  ['para mi seguro de barco',
#   'De acuerdo. ¿Con qué puedo ayudarle con respecto a su seguro de barco'],
#  ['De acuerdo. ¿Con qué puedo ayudarle con respecto a su seguro de barco',
#   '¿Cuánto estoy asegurado?'],
#  ['¿Cuánto estoy asegurado?', 'usted está asegurado por 50.000'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi política.'],
#  ['Tengo una pregunta sobre mi política.', 'Claro. ¿Qué te gustaría saber?'],
#  ['Claro. ¿Qué te gustaría saber?', '¿Qué cubre?'],
#  ['¿Qué cubre?',
#   'Su política actual cubre los daños causados por el agua, el fuego y los actos de Dios.'],
#  ['Su política actual cubre los daños causados por el agua, el fuego y los actos de Dios.',
#   'En mi casa.'],
#  ['En mi casa.', 'Sí, en tu casa.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Sí, necesito ayuda con mi póliza.'],
#  ['Sí, necesito ayuda con mi póliza.', 'seguro. ¿Qué necesitas?'],
#  ['seguro. ¿Qué necesitas?',
#   'Sólo necesito conocer algunas coberturas de políticas. ¿Puedes ayudar con eso?'],
#  ['Sólo necesito conocer algunas coberturas de políticas. ¿Puedes ayudar con eso?',
#   'Sí, puedo ayudar.'],
#  ['Sí, puedo ayudar.', '¿Mi póliza cubre los daños causados por el agua?'],
#  ['¿Mi póliza cubre los daños causados por el agua?',
#   '¿Cuál es su número de póliza?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'necesita algo de información'],
#  ['necesita algo de información', '¿De qué tipo?'],
#  ['¿De qué tipo?', '¿Tienes mi cuenta arriba?'],
#  ['¿Tienes mi cuenta arriba?', 'Sí'],
#  ['Sí', '¿Cuál es mi prima de seguro médico?'],
#  ['¿Cuál es mi prima de seguro médico?', 'Sus 5 dólares al mes'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo una pregunta sobre mi póliza de seguro.'],
#  ['Tengo una pregunta sobre mi póliza de seguro.',
#   'Claro, puedo ayudarte con preguntas sobre tu polocy de seguro ¿qué te gustaría saber?'],
#  ['Claro, puedo ayudarte con preguntas sobre tu polocy de seguro ¿qué te gustaría saber?',
#   '¿Qué cubre mi póliza actual?'],
#  ['¿Qué cubre mi póliza actual?',
#   'Bien, permítanme buscar información sobre lo que cubre su política actual..... Su política actual cubre los daños causados por el agua, el fuego y los actos de Dios'],
#  ['Bien, permítanme buscar información sobre lo que cubre su política actual..... Su política actual cubre los daños causados por el agua, el fuego y los actos de Dios',
#   '¿El agua es igual que las inundaciones o las inundaciones no están cubiertas?'],
#  ['¿El agua es igual que las inundaciones o las inundaciones no están cubiertas?',
#   'Las inundaciones están cubiertas'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Qué seguro médico tenemos?'],
#  ['¿Qué seguro médico tenemos?', 'no tenemos un seguro médico'],
#  ['no tenemos un seguro médico', '¿Es pemio?'],
#  ['¿Es pemio?', 'Siento no entender la pregunta'],
#  ['Siento no entender la pregunta', '¿Qué tenemos?'],
#  ['¿Qué tenemos?', 'la compañía tiene Aetna y Kaiser'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Quiero saber sobre política'],
#  ['Quiero saber sobre política',
#   'Claro, puedo ayudarte con las pólizas de seguro.'],
#  ['Claro, puedo ayudarte con las pólizas de seguro.',
#   '¿Tienes mi cuenta levantada?'],
#  ['¿Tienes mi cuenta levantada?',
#   'Tengo la información que se guardó automáticamente de lo que se introdujo.'],
#  ['Tengo la información que se guardó automáticamente de lo que se introdujo.',
#   'cubre los daños causados por el agua?'],
#  ['cubre los daños causados por el agua?',
#   'Un momento por favor mientras lo compruedo para usted [ . . . ] Desafortunadamente, su póliza de seguro no cubre los daños causados por el agua.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola me gustaría saber cuánto estoy asegurado para hoy'],
#  ['Hola me gustaría saber cuánto estoy asegurado para hoy',
#   'Sí. ¿Qué quieres decir con/.?'],
#  ['Sí. ¿Qué quieres decir con/.?',
#   'Veo que usted es un bot que representa a mi compañía de seguros me gustaría saber cuánto estoy asegurado para'],
#  ['Veo que usted es un bot que representa a mi compañía de seguros me gustaría saber cuánto estoy asegurado para',
#   'Tu asegurado para todo. En cuanto a lo que he comprobado su cuenta todo estaba asegurado para su.'],
#  ['Tu asegurado para todo. En cuanto a lo que he comprobado su cuenta todo estaba asegurado para su.',
#   'Bien perfecto'],
#  ['Bien perfecto', '¿Todavía estás ahí?\\ ¿Hay algo más?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puedes ayudarme a averiguar algunas cosas sobre mi seguro?'],
#  ['¿Puedes ayudarme a averiguar algunas cosas sobre mi seguro?',
#   'Sí, puedo ayudar con eso.'],
#  ['Sí, puedo ayudar con eso.',
#   'Ok mi póliza es 238393483648946334986 Necesito saber cuánto estoy asegurado para'],
#  ['Ok mi póliza es 238393483648946334986 Necesito saber cuánto estoy asegurado para',
#   'Ok, ¿de qué plan de seguro estás preguntando?'],
#  ['Ok, ¿de qué plan de seguro estás preguntando?', 'Mi motocicleta'],
#  ['Mi motocicleta',
#   'Ok, usted tiene $15,000 en responsabilidad. y $20,000 en medicina.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Quiero saber si mi póliza cubre los daños causados por el agua. Mi número de póliza es 1234567890.'],
#  ['Quiero saber si mi póliza cubre los daños causados por el agua. Mi número de póliza es 1234567890.',
#   'Por supuesto, déjame comprobarlo. No, no parece que su póliza cubra los daños causados por el agua'],
#  ['Por supuesto, déjame comprobarlo. No, no parece que su póliza cubra los daños causados por el agua',
#   '¿Qué cubre entonces?'],
#  ['¿Qué cubre entonces?',
#   'Su política cubre sólo el agua, el fuego y los actos de Dios'],
#  ['Su política cubre sólo el agua, el fuego y los actos de Dios',
#   '¿Los daños causados por el agua no están incluidos bajo el agua?'],
#  ['¿Los daños causados por el agua no están incluidos bajo el agua?',
#   'Lo siento. Debe haber habido un error. Su política sólo incluye fuego y actos de dios'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo preguntas sobre política'],
#  ['Tengo preguntas sobre política',
#   'Ciertamente, ¿cuál es su número de póliza'],
#  ['Ciertamente, ¿cuál es su número de póliza', '21412489'],
#  ['21412489', 'Está bien, déjame buscar eso. ¿Cuál es su pregunta'],
#  ['Está bien, déjame buscar eso. ¿Cuál es su pregunta',
#   '¿qué cubre mi póliza actual?'],
#  ['¿qué cubre mi póliza actual?',
#   'Su política cubre los daños causados por el agua, el fuego y los actos de Dios'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi seguro'],
#  ['Tengo una pregunta sobre mi seguro',
#   'Puedo ayudar con eso. ¿Cuál es tu pregunta?'],
#  ['Puedo ayudar con eso. ¿Cuál es tu pregunta?',
#   '¿puede decirme lo que mi política cubre'],
#  ['¿puede decirme lo que mi política cubre',
#   'Puedo hacer eso. Necesitaré tu número de póliza'],
#  ['Puedo hacer eso. Necesitaré tu número de póliza', 'K87657'],
#  ['K87657',
#   'Bien, su póliza proporciona cobertura para los daños causados por el agua, el fuego y los actos de Dios'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo una pregunta sobre mi póliza de seguro'],
#  ['Tengo una pregunta sobre mi póliza de seguro',
#   '¿De qué plan de seguro estás hablando?'],
#  ['¿De qué plan de seguro estás hablando?',
#   'Me refiero a mi póliza de seguro de vida'],
#  ['Me refiero a mi póliza de seguro de vida', 'Bien. ¿Qué te gustaría saber?'],
#  ['Bien. ¿Qué te gustaría saber?', '¿Cuánto estoy asegurado para'],
#  ['¿Cuánto estoy asegurado para', '$250,000'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Tengo una pregunta rápida sobre mi seguridad?'],
#  ['¿Tengo una pregunta rápida sobre mi seguridad?', 'Sí, por favor, adelante'],
#  ['Sí, por favor, adelante',
#   'Me preguntaba cuánto estoy asegurado por incaso de un accidente'],
#  ['Me preguntaba cuánto estoy asegurado por incaso de un accidente',
#   '¿Qué plan estás pidiendo?'],
#  ['¿Qué plan estás pidiendo?', 'Mi seguro de coche'],
#  ['Mi seguro de coche', 'usted está cubierto hasta $10,000'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi política'],
#  ['Tengo una pregunta sobre mi política',
#   '¿Puedo obtener su nombre y número de póliza, por favor?'],
#  ['¿Puedo obtener su nombre y número de póliza, por favor?',
#   'Elroy Bink, 1256'],
#  ['Elroy Bink, 1256', 'Genial, señor Bink. ¿De qué necesitas información>?'],
#  ['Genial, señor Bink. ¿De qué necesitas información>?',
#   '¿Mi póliza cubre los daños causados por el agua?'],
#  ['¿Mi póliza cubre los daños causados por el agua?',
#   'Lo siento, la política actual no cubre los daños causados por el agua. ¿Te gustaría añadirlo hoy?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito información sobre mi póliza de seguro.'],
#  ['Necesito información sobre mi póliza de seguro.',
#   'Ciertamente puedo ayudar con eso. ¿Puedo tener su número de póliza?'],
#  ['Ciertamente puedo ayudar con eso. ¿Puedo tener su número de póliza?',
#   '#353535353'],
#  ['#353535353', '¿Qué información necesita con respecto a su póliza?'],
#  ['¿Qué información necesita con respecto a su póliza?',
#   '¿Cuánto estoy asegurado?'],
#  ['¿Cuánto estoy asegurado?', '¿Qué plan exacto está preguntando hoy?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola, me gustaría su ayuda con mi política'],
#  ['Hola, me gustaría su ayuda con mi política',
#   'Claro, puedo ayudarte con tu póliza de seguro ¿qué te gustaría saber?'],
#  ['Claro, puedo ayudarte con tu póliza de seguro ¿qué te gustaría saber?',
#   'Me pregunto cómo puedo cambiar los términos de mi póliza de seguro de vida. ¿Es algo con lo que puedes ayudarme?'],
#  ['Me pregunto cómo puedo cambiar los términos de mi póliza de seguro de vida. ¿Es algo con lo que puedes ayudarme?',
#   'Si desea cambiar sus términos de seguro de vida tendrá que hacer una cita con nuestro corredor de seguros'],
#  ['Si desea cambiar sus términos de seguro de vida tendrá que hacer una cita con nuestro corredor de seguros',
#   '¿Así que no hay forma de que pueda modificar mi política en línea a través de ti?'],
#  ['¿Así que no hay forma de que pueda modificar mi política en línea a través de ti?',
#   'No, tendrás que llamar a tu corredor ¿quieres el número de teléfono?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi política.'],
#  ['Tengo una pregunta sobre mi política.', 'seguro'],
#  ['seguro', 'Necesito saber cuánto estoy asegurado para'],
#  ['Necesito saber cuánto estoy asegurado para', '¿qué plan?'],
#  ['¿qué plan?', 'Mi seguro de coche.'],
#  ['Mi seguro de coche.', 'acount number?\\'],
#  ['Hola, ¿en qué puedo ayudarle?', 'ayúdame a revisar mi póliza de seguro'],
#  ['ayúdame a revisar mi póliza de seguro', '¿Qué quieres saber?'],
#  ['¿Qué quieres saber?', '¿Qué cubre mi seguro?'],
#  ['¿Qué cubre mi seguro?', '¿Cuál es su número de póliza?'],
#  ['¿Cuál es su número de póliza?', '343454'],
#  ['343454',
#   'Su política actual cubre los daños causados por el agua, el fuego y los actos de Dios'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Necesito información de seguro'],
#  ['Necesito información de seguro',
#   'Puedo ayudar con la información del seguro.'],
#  ['Puedo ayudar con la información del seguro.',
#   'Bien, ¿cuál es mi prima de seguro médico?'],
#  ['Bien, ¿cuál es mi prima de seguro médico?',
#   'Lamento informarle en este momento que no tiene un plan de seguro médico.'],
#  ['Lamento informarle en este momento que no tiene un plan de seguro médico.',
#   'Qué. Acabo de perder mi pierna en un accidente de ciclomotor.'],
#  ['Qué. Acabo de perder mi pierna en un accidente de ciclomotor.',
#   'Lamento oír eso y desafortunadamente no tiene seguro médico para ayudar a cubrir sus gastos.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Me gustaría saber cuánto estoy asegurado para'],
#  ['Me gustaría saber cuánto estoy asegurado para',
#   '¿Podría especificar qué plan de seguro?'],
#  ['¿Podría especificar qué plan de seguro?', 'Mi seguro de vida'],
#  ['Mi seguro de vida', 'seguro de vida está cubierto por 1 millón al año.'],
#  ['seguro de vida está cubierto por 1 millón al año.',
#   '¿Es ese término o seguro de vida completo?'],
#  ['¿Es ese término o seguro de vida completo?', 'durante un año.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Estoy interesado en cambiar los términos de mi póliza de seguro de vida.'],
#  ['Estoy interesado en cambiar los términos de mi póliza de seguro de vida.',
#   'usted tiene que hacer una cita'],
#  ['usted tiene que hacer una cita', 'Ok, ¿tienes tiempo disponible mañana?'],
#  ['Ok, ¿tienes tiempo disponible mañana?', 'claro, ¿quieres que lo programe?'],
#  ['claro, ¿quieres que lo programe?', 'Sí.'],
#  ['Sí.', '¿Algo más?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo algunas preguntas sobre mi póliza de seguro'],
#  ['Tengo algunas preguntas sobre mi póliza de seguro',
#   'Sí, puedo ayudar lo mejor que pueda.'],
#  ['Sí, puedo ayudar lo mejor que pueda.',
#   'Primero te daré mi número de póliza y luego puedes obtener mi información 568768866'],
#  ['Primero te daré mi número de póliza y luego puedes obtener mi información 568768866',
#   'Bien, bien hecho.'],
#  ['Bien, bien hecho.', '¿Cómo cambiaría los términos de mi seguro de vida?'],
#  ['¿Cómo cambiaría los términos de mi seguro de vida?',
#   'Usted tendrá que hacer una cita con su corredor de seguros.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Hola quiero información sobre mi seguro'],
#  ['Hola quiero información sobre mi seguro',
#   'Claro que puedo ayudarte con eso, ¿qué compañía de seguros tienes?'],
#  ['Claro que puedo ayudarte con eso, ¿qué compañía de seguros tienes?',
#   'La póliza de seguro no es #1264616 ¿puedes sacar esa información por mí?'],
#  ['La póliza de seguro no es #1264616 ¿puedes sacar esa información por mí?',
#   'Sí, dame un segundo.'],
#  ['Sí, dame un segundo.', 'Bien'],
#  ['Bien',
#   'Parece que no tienes seguro en este momento, acabas de empezar tu trabajo y no entra en acción durante 6 meses'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Hola, tengo preguntas sobre mi seguro?'],
#  ['Hola, tengo preguntas sobre mi seguro?',
#   'Claro, ¿cuál es su número de póliza?'],
#  ['Claro, ¿cuál es su número de póliza?', '1119kj-00'],
#  ['1119kj-00', 'Ok, ¿qué te gustaría saber?'],
#  ['Ok, ¿qué te gustaría saber?', '¿Tengo cobertura sísmica?'],
#  ['¿Tengo cobertura sísmica?',
#   'Sí, pero no cobertura de daños causados por el agua.'],
#  ['Sí, pero no cobertura de daños causados por el agua.',
#   'Ok, ¿cuánto me costará añadir daño de agua a mi póliza?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Me gustaría encontrar información sobre mi política'],
#  ['Me gustaría encontrar información sobre mi política',
#   'Claro, ¿cómo puedo ayudar'],
#  ['Claro, ¿cómo puedo ayudar',
#   '¿Podría decirme si mi póliza actual cubre los daños causados por el agua?'],
#  ['¿Podría decirme si mi póliza actual cubre los daños causados por el agua?',
#   'Desafortunadamente su política actual no cubre los daños causados por el agua'],
#  ['Desafortunadamente su política actual no cubre los daños causados por el agua',
#   'Muy bien, ¿hay alguna manera de añadir eso a mi póliza?'],
#  ['Muy bien, ¿hay alguna manera de añadir eso a mi póliza?',
#   'Sí, pero sólo para hacerle saber esto puede tener un impacto en sus primas'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito información sobre cómo cambiar mi póliza de seguro de vida.'],
#  ['Necesito información sobre cómo cambiar mi póliza de seguro de vida.',
#   '¡absolutamente! ¿Qué información está buscando cambiar?'],
#  ['¡absolutamente! ¿Qué información está buscando cambiar?',
#   '¿Puede decirme cómo puedo cambiar los términos de mi póliza de seguro de vida?'],
#  ['¿Puede decirme cómo puedo cambiar los términos de mi póliza de seguro de vida?',
#   'Con el fin de cambiar sus primas de pólizas de seguro de vida tendrá que hablar con su corredor de seguros. Recomiendo hacer una cita con ellos.'],
#  ['Con el fin de cambiar sus primas de pólizas de seguro de vida tendrá que hablar con su corredor de seguros. Recomiendo hacer una cita con ellos.',
#   '¿Cómo hago eso?'],
#  ['¿Cómo hago eso?', 'Usted tendrá que llamar a su corredor al 565-7852.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'eh'],
#  ['eh', '¿En qué puedo ayudarle?'],
#  ['¿En qué puedo ayudarle?', '¿Puedo preguntarte?'],
#  ['¿Puedo preguntarte?', 'Siento no entenderlo.'],
#  ['Siento no entenderlo.', '¿Cuánto estás asegurado?'],
#  ['¿Cuánto estás asegurado?',
#   'Puedo ayudarle, por favor ingrese su número de póliza.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Cuál es mi actualización del seguro médico?'],
#  ['¿Cuál es mi actualización del seguro médico?', 'Dame tu número de póliza'],
#  ['Dame tu número de póliza', '364736438'],
#  ['364736438', 'Actualmente no tiene un plan con nosotros'],
#  ['Actualmente no tiene un plan con nosotros',
#   'Creo que todavía tengo mi prima'],
#  ['Creo que todavía tengo mi prima', 'Su cuenta expiró hace 2 meses'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola, tengo una pregunta sobre mi póliza de seguro.'],
#  ['Hola, tengo una pregunta sobre mi póliza de seguro.',
#   '¿Qué quieres saber?'],
#  ['¿Qué quieres saber?', '¿Cuánto cuesta mi prima?'],
#  ['¿Cuánto cuesta mi prima?', '$300.'],
#  ['$300.', '¿Hay otros planes que sean más baratos?'],
#  ['¿Hay otros planes que sean más baratos?',
#   'Sí, hay uno disponible por $200.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Necesito ayuda rápida hoy.'],
#  ['Necesito ayuda rápida hoy.',
#   'Ciertamente, ¿cómo puedo ayudarle con su póliza de seguro'],
#  ['Ciertamente, ¿cómo puedo ayudarle con su póliza de seguro',
#   'Tengo una pregunta sobre mi seguro. ¿Qué cubre mi póliza?'],
#  ['Tengo una pregunta sobre mi seguro. ¿Qué cubre mi póliza?',
#   'Déjame comprobarlo por ti. ¿Cuál es su número de póliza'],
#  ['Déjame comprobarlo por ti. ¿Cuál es su número de póliza',
#   '¿Dónde puedo encontrar eso?'],
#  ['¿Dónde puedo encontrar eso?', 'Sobre su política, por supuesto'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Me gustaría saber cómo puedo cambiar los términos de mi póliza de seguro de vida'],
#  ['Me gustaría saber cómo puedo cambiar los términos de mi póliza de seguro de vida',
#   '¿Me permite el número de póliza, por favor?'],
#  ['¿Me permite el número de póliza, por favor?', '453252345235'],
#  ['453252345235', 'Gracias. ¿Qué términos desea cambiar?'],
#  ['Gracias. ¿Qué términos desea cambiar?',
#   'Quiero cambiar la cantidad de dinero que le doy a mi hijo'],
#  ['Quiero cambiar la cantidad de dinero que le doy a mi hijo',
#   'Para ese tipo de cambio, tendrá que ponerse en contacto con su corredor de seguros. Esto no se puede hacer en línea.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo una pregunta sobre mi compañía de seguros.'],
#  ['Tengo una pregunta sobre mi compañía de seguros.',
#   'Puedo tratar de ayudarte con eso.'],
#  ['Puedo tratar de ayudarte con eso.',
#   '¿Puedes revisar mi acoount WERY235FH y decirme para qué estoy asegurado?'],
#  ['¿Puedes revisar mi acoount WERY235FH y decirme para qué estoy asegurado?',
#   'Un momento.'],
#  ['Un momento.', 'De acuerdo'],
#  ['De acuerdo',
#   'Mis registros muestran que tienes seguro de vida y seguro contra inundaciones.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Quiero saber cómo cambiar los términos de mi póliza de seguro de vida.'],
#  ['Quiero saber cómo cambiar los términos de mi póliza de seguro de vida.',
#   'Gracias por ponerse en contacto con la compañía de seguros KM. Verificaremos su solicitud en un momento'],
#  ['Gracias por ponerse en contacto con la compañía de seguros KM. Verificaremos su solicitud en un momento',
#   '¿Puedes responder a mi pregunta?'],
#  ['¿Puedes responder a mi pregunta?',
#   'Lo siento, pero tienes que hacer una cita con tu corredor de seguros'],
#  ['Lo siento, pero tienes que hacer una cita con tu corredor de seguros',
#   '¿Cómo puedo preparar una cita de este tipo?'],
#  ['¿Cómo puedo preparar una cita de este tipo?',
#   'póngase en contacto con el corredor de seguros.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola, ¿tenía alguna pregunta sobre mi política?'],
#  ['Hola, ¿tenía alguna pregunta sobre mi política?',
#   'Claro, ¿puedo tener tu número de póliza?'],
#  ['Claro, ¿puedo tener tu número de póliza?', 'Claro, 1234567890.'],
#  ['Claro, 1234567890.',
#   'Tengo tu póliza levantada ahora. ¿Cómo puedo ayudar?'],
#  ['Tengo tu póliza levantada ahora. ¿Cómo puedo ayudar?',
#   'Sí, me preguntaba si el seguro de mi dueño de casa. Tiene daños causados por el agua.'],
#  ['Sí, me preguntaba si el seguro de mi dueño de casa. Tiene daños causados por el agua.',
#   'RIght ahora, su póliza actual no cubre los daños causados por el agua.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Me gustaría preguntar por mi póliza de seguro por favor'],
#  ['Me gustaría preguntar por mi póliza de seguro por favor',
#   'Claro que adelante, por favor.'],
#  ['Claro que adelante, por favor.',
#   '¿Puedes decirme cuál es mi prima de seguro médico?'],
#  ['¿Puedes decirme cuál es mi prima de seguro médico?',
#   '¿Puedes darme tu número de póliza para que pueda buscarte eso?'],
#  ['¿Puedes darme tu número de póliza para que pueda buscarte eso?',
#   'mi número de póliza es 1234441'],
#  ['mi número de póliza es 1234441',
#   'Gracias. Su prima es de $200 al mes. Lo siento.'],
#  ['Gracias. Su prima es de $200 al mes. Lo siento.',
#   '¿Hay alguna manera de que pueda bajar eso?'],
#  ['¿Hay alguna manera de que pueda bajar eso?', 'Saqué la cuenta equivocada.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito ayuda con una pregunta de seguro, por favor'],
#  ['Necesito ayuda con una pregunta de seguro, por favor',
#   'Me encantaría ayudarte. ¿Cuál es tu pregunta?'],
#  ['Me encantaría ayudarte. ¿Cuál es tu pregunta?',
#   'Mi número de póliza es IJ847-089. ¿Puedes decirme cuánto estoy seguro?'],
#  ['Mi número de póliza es IJ847-089. ¿Puedes decirme cuánto estoy seguro?',
#   'Su política es tanto para el hogar como para el automóvil. ¿De qué quieres información?'],
#  ['Su política es tanto para el hogar como para el automóvil. ¿De qué quieres información?',
#   'Me gustaría información sobre mi seguro de automóvil. Alguien me habló y yo estoy en el hospital. Tuve que someterse a una cirugía y voy a estar en fisioterapia durante al menos 3 meses.'],
#  ['Me gustaría información sobre mi seguro de automóvil. Alguien me habló y yo estoy en el hospital. Tuve que someterse a una cirugía y voy a estar en fisioterapia durante al menos 3 meses.',
#   'Siento mucho oír eso. Estás asegurado por 100.000. Esperemos que eso cubra todo lo que necesita.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Necesito ayuda con mi seguro, por favor'],
#  ['Necesito ayuda con mi seguro, por favor', '¿En qué puedo ayudarle?'],
#  ['¿En qué puedo ayudarle?', '¿Cuánto está asegurado mi auto?'],
#  ['¿Cuánto está asegurado mi auto?',
#   '¿Cuál es el número de póliza, por favor?'],
#  ['¿Cuál es el número de póliza, por favor?', '3309743093434943486'],
#  ['3309743093434943486', 'ese vehículo está asegurado por $60,000'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo una pregunta sobre mi póliza de seguro'],
#  ['Tengo una pregunta sobre mi póliza de seguro', 'Sí, ¿qué tiene tu seguro?'],
#  ['Sí, ¿qué tiene tu seguro?',
#   '¿Cómo cambio los términos de mi póliza de seguro de vida?'],
#  ['¿Cómo cambio los términos de mi póliza de seguro de vida?',
#   'tendrá que ponerse en contacto con su corredor para que'],
#  ['tendrá que ponerse en contacto con su corredor para que',
#   '¿Quién es mi hermano otra vez? *corredor'],
#  ['¿Quién es mi hermano otra vez? *corredor', 'su corredor es AAA'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Necesita información de seguro'],
#  ['Necesita información de seguro',
#   '¿Con qué política y sartén necesita ayuda?'],
#  ['¿Con qué política y sartén necesita ayuda?', 'Política nº 25636976'],
#  ['Política nº 25636976', '*plan'],
#  ['*plan', '¿Cuánto estoy asegurado?'],
#  ['¿Cuánto estoy asegurado?',
#   'Bien, tienes seguro de hogar, vida y auto. ¿Con qué tipo de directiva necesita ayuda?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'necesito saber lo que cubre mi póliza'],
#  ['necesito saber lo que cubre mi póliza',
#   'Su política es una política básica del hogar. Usted está cubierto de daños por incendios y viento, No cubrimos daños o daños causados por el agua por terremotos'],
#  ['Su política es una política básica del hogar. Usted está cubierto de daños por incendios y viento, No cubrimos daños o daños causados por el agua por terremotos',
#   'Estás seguro'],
#  ['Estás seguro',
#   'Sí. Puedo comprobar que sí No cubrimos actos de Dios que incluyen daños causados por el agua y daños causados por desastres naturales'],
#  ['Sí. Puedo comprobar que sí No cubrimos actos de Dios que incluyen daños causados por el agua y daños causados por desastres naturales',
#   '¿qué pasa con la caída de ramas'],
#  ['¿qué pasa con la caída de ramas',
#   'La caída de ramas caería bajo actos de Dios. Usted ya ha optado por la cobertura del viento ya que está en una llanura de viento'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito información sobre mi seguro médico ¿puedes ayudarme con esto?'],
#  ['Necesito información sobre mi seguro médico ¿puedes ayudarme con esto?',
#   'Estaría más que feliz de ayudarte con eso'],
#  ['Estaría más que feliz de ayudarte con eso',
#   'Ok, me gustaría saber cuál es mi prima de seguro por favor'],
#  ['Ok, me gustaría saber cuál es mi prima de seguro por favor',
#   '¿Tiene que almacenar un sistema automatizado para extraer la información de su cuenta que parece que su cuenta está inactiva y que actualmente no tiene un plan de seguro médico'],
#  ['¿Tiene que almacenar un sistema automatizado para extraer la información de su cuenta que parece que su cuenta está inactiva y que actualmente no tiene un plan de seguro médico',
#   '¡¡Qué!! pero, ¿cómo sucedió esto? ¿Qué hago?'],
#  ['¡¡Qué!! pero, ¿cómo sucedió esto? ¿Qué hago?',
#   'No pagó su factura todo lo que necesita hacer es pagar sus facturas vencidas y reactivar su cuenta'],
#  ['Hola, ¿en qué puedo ayudarle?', 'ayúdame con mi seguro'],
#  ['ayúdame con mi seguro', '¿De qué plan de seguro estás preguntando?'],
#  ['¿De qué plan de seguro estás preguntando?', 'para mi seguro de automóvil'],
#  ['para mi seguro de automóvil', '¿Qué te gustaría saber?'],
#  ['¿Qué te gustaría saber?', '¿Cuánto estoy asegurado?'],
#  ['¿Cuánto estoy asegurado?', 'Hasta $150,000.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puede decirme si mi póliza cubre los daños causados por el agua?'],
#  ['¿Puede decirme si mi póliza cubre los daños causados por el agua?',
#   '¿tiene el número de póliza'],
#  ['¿tiene el número de póliza', '123456'],
#  ['123456', 'no ese número de póliza no cubre los daños causados por el agua'],
#  ['no ese número de póliza no cubre los daños causados por el agua',
#   '¿Puedo agregarlo a mi póliza?'],
#  ['¿Puedo agregarlo a mi póliza?', 'Sí'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola me gustaría saber cuánto estoy asegurado para mi póliza de seguro de vida #39393'],
#  ['Hola me gustaría saber cuánto estoy asegurado para mi póliza de seguro de vida #39393',
#   'Me encantaría ayudarte. Sólo para aclarar, ¿estamos revisando la política del Seguro de Vida para #39393?'],
#  ['Me encantaría ayudarte. Sólo para aclarar, ¿estamos revisando la política del Seguro de Vida para #39393?',
#   'Eso es correcto.'],
#  ['Eso es correcto.',
#   '¿Podría verificar los últimos cuatro dígitos de su número SSN o su código de negocio, por favor?'],
#  ['¿Podría verificar los últimos cuatro dígitos de su número SSN o su código de negocio, por favor?',
#   'Sí, son 0000'],
#  ['Sí, son 0000',
#   'Gracias por la información. Nuestros registros muestran que los pagos actuales de su seguro de vida oscilan entre $10,000 y $300,000.'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Puedes ayudarme sobre mi seguro?'],
#  ['¿Puedes ayudarme sobre mi seguro?',
#   'absolutamente. ¿De qué política está preguntando?'],
#  ['absolutamente. ¿De qué política está preguntando?',
#   '¿Quiero saber cuánto aseguré en mi seguro?'],
#  ['¿Quiero saber cuánto aseguré en mi seguro?',
#   '¿De qué plan estás preguntando?'],
#  ['¿De qué plan estás preguntando?', '¿Quiero saber cuánto?'],
#  ['¿Quiero saber cuánto?',
#   'Lo siento, pero para ayudarte necesito saber de qué plan de seguro quieres información. ¿Es auto, vida, propietarios, inquilinos, seguro de conducir?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo una pregunta sobre mi póliza de seguro.'],
#  ['Tengo una pregunta sobre mi póliza de seguro.', '¿Cuál es tu pregunta?'],
#  ['¿Cuál es tu pregunta?',
#   '¿Cuál es la cobertura de mi póliza de seguro de vida?'],
#  ['¿Cuál es la cobertura de mi póliza de seguro de vida?',
#   'Dependiendo de la edad de maduración, su póliza pagará entre $30,000 y $40,000.'],
#  ['Dependiendo de la edad de maduración, su póliza pagará entre $30,000 y $40,000.',
#   '¿Y cuál es mi pago mensual de prima?'],
#  ['¿Y cuál es mi pago mensual de prima?',
#   'Su pago mensual actual de prima es de $26.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puede ayudarme con mi compañía de seguros?'],
#  ['¿Puede ayudarme con mi compañía de seguros?', 'Sí'],
#  ['Sí', '¿Cuánto estoy asegurado?'],
#  ['¿Cuánto estoy asegurado?', '¿Cuál es tu cuenta #?'],
#  ['¿Cuál es tu cuenta #?', 'WERT345RT5'],
#  ['WERT345RT5', '¿Qué plan de seguro?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo una pregunta sobre mi póliza de seguro.'],
#  ['Tengo una pregunta sobre mi póliza de seguro.',
#   'seguro. Veo que tienes políticas de auto, hogar y vida con nosotros. ¿De qué política estás preguntando?'],
#  ['seguro. Veo que tienes políticas de auto, hogar y vida con nosotros. ¿De qué política estás preguntando?',
#   'Mi seguro de automóvil'],
#  ['Mi seguro de automóvil',
#   'Muy bien, ¿qué le gustaría saber sobre su política de auto?'],
#  ['Muy bien, ¿qué le gustaría saber sobre su política de auto?',
#   'Necesito saber cuánto estoy asegurado para'],
#  ['Necesito saber cuánto estoy asegurado para',
#   'Tienes $500,00 en automovilista sin seguro.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puede ayudar con una pregunta de seguro?'],
#  ['¿Puede ayudar con una pregunta de seguro?',
#   'ok, ¿cuál es su número de cuenta?'],
#  ['ok, ¿cuál es su número de cuenta?', '3'],
#  ['3', 'Ok, ¿cuál es tu pregunta?'],
#  ['Ok, ¿cuál es tu pregunta?',
#   '¿Mi póliza cubre los daños causados por el agua?'],
#  ['¿Mi póliza cubre los daños causados por el agua?',
#   'su política no cubre que'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Cuáles son mis civers de políticas actuales?'],
#  ['¿Cuáles son mis civers de políticas actuales?',
#   'Por favor, especifique su número de póliza'],
#  ['Por favor, especifique su número de póliza', '123654'],
#  ['123654', 'Levantando información ahora.'],
#  ['Levantando información ahora.', 'no estar esperando'],
#  ['no estar esperando',
#   'Su política actual cubre los daños causados por el fuego, el agua y los actos de Dios.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Necesito ayuda con mi seguro'],
#  ['Necesito ayuda con mi seguro', '¿Cómo puedo ayudarle con su seguro?'],
#  ['¿Cómo puedo ayudarle con su seguro?', 'Necesito saber mi prima de premiu'],
#  ['Necesito saber mi prima de premiu',
#   '¿Puedes darme tu apellido y los últimos cuatro dígitos de tu social?'],
#  ['¿Puedes darme tu apellido y los últimos cuatro dígitos de tu social?',
#   'Smith, 8877'],
#  ['Smith, 8877',
#   'Nuestros registros muestran que actualmente no tiene un plan de seguro médico con nuestra compañía. ¿Está seguro de que está en contacto con la empresa correcta?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre política'],
#  ['Tengo una pregunta sobre política',
#   'Muy bien, puedo ayudarte con eso. ¿Puedo tener su número de póliza?'],
#  ['Muy bien, puedo ayudarte con eso. ¿Puedo tener su número de póliza?',
#   '2134512'],
#  ['2134512', 'Un segundo... Muy bien, ¿con qué puedo ayudarte?'],
#  ['Un segundo... Muy bien, ¿con qué puedo ayudarte?',
#   'cubre los daños causados por el agua?'],
#  ['cubre los daños causados por el agua?',
#   'Desafortunadamente parece que su póliza no cubre los daños causados por el agua.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi seguro'],
#  ['Tengo una pregunta sobre mi seguro', '¿Cuál es la pregunta?'],
#  ['¿Cuál es la pregunta?',
#   '¿cómo puedo cambiar los términos de mi póliza de seguro de vida?'],
#  ['¿cómo puedo cambiar los términos de mi póliza de seguro de vida?',
#   'usted necesita llenar algunos formularios en línea'],
#  ['usted necesita llenar algunos formularios en línea',
#   '¿Puedes llenarlo para mí?'],
#  ['¿Puedes llenarlo para mí?', 'No estoy equipado para responder a eso'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo preguntas sobre mi política actual.'],
#  ['Tengo preguntas sobre mi política actual.',
#   'seguro. Puedo responder a cualquier pregunta política que pueda tener.'],
#  ['seguro. Puedo responder a cualquier pregunta política que pueda tener.',
#   '¿Mi póliza cubre los daños causados por las inundaciones?'],
#  ['¿Mi póliza cubre los daños causados por las inundaciones?',
#   '¿Cuál es su número de póliza?'],
#  ['¿Cuál es su número de póliza?', '23423874863274'],
#  ['23423874863274',
#   'Sí. Su póliza cubre los daños causados por el agua, incluido el causado por las inundaciones.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Sí, tengo una pregunta de seguro'],
#  ['Sí, tengo una pregunta de seguro',
#   'Ciertamente, puedo ayudar con las preguntas del seguro. ¿Qué te gustaría saber?'],
#  ['Ciertamente, puedo ayudar con las preguntas del seguro. ¿Qué te gustaría saber?',
#   '¿Estoy cubierto si me escagón de mi propio avión y me estrellaré contra mi propio auto?'],
#  ['¿Estoy cubierto si me escagón de mi propio avión y me estrellaré contra mi propio auto?',
#   'Déjame ver eso. Parece que no estoy equipado para responder a esa pregunta.'],
#  ['Déjame ver eso. Parece que no estoy equipado para responder a esa pregunta.',
#   'ok gracias de todos modos'],
#  ['ok gracias de todos modos',
#   'No hay problema. ¿Alguna pregunta más general con la que pueda ayudar?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Quiero información sobre mi póliza de seguro.'],
#  ['Quiero información sobre mi póliza de seguro.',
#   'Intentaré cumplir con sus peticiones.'],
#  ['Intentaré cumplir con sus peticiones.',
#   '¿Mi póliza cubre los daños causados por el secuestro de alienígenas?'],
#  ['¿Mi póliza cubre los daños causados por el secuestro de alienígenas?',
#   'Estás cubierto por eso, sí.'],
#  ['Estás cubierto por eso, sí.',
#   '¿Así que pagarás por los electrodos que me implantaron para que me saquen?'],
#  ['¿Así que pagarás por los electrodos que me implantaron para que me saquen?',
#   'Si tenemos las herramientas para confirmar esto.'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Puedes ayudarme con el seguro?'],
#  ['¿Puedes ayudarme con el seguro?', 'Sí, ¿cuál es su número de cuenta?'],
#  ['Sí, ¿cuál es su número de cuenta?', 'Mi número de póliza es 5734817'],
#  ['Mi número de póliza es 5734817', 'Tengo tu cuenta levantada'],
#  ['Tengo tu cuenta levantada',
#   'Para mi seguro de vida, ¿cuánto estoy cubierto de irght ahora?'],
#  ['Para mi seguro de vida, ¿cuánto estoy cubierto de irght ahora?',
#   '¿Esto es para su plan de automóvil o hogar?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puedo preguntar sobre la política actual?'],
#  ['¿Puedo preguntar sobre la política actual?', 'Sí'],
#  ['Sí', '¿Cuál es mi estado actual?'],
#  ['¿Cuál es mi estado actual?', 'Su estado es bueno'],
#  ['Su estado es bueno', '¿Hasta cuándo es la renovación de mi insuance?'],
#  ['¿Hasta cuándo es la renovación de mi insuance?', 'El año que viene'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puede ayudar con mi póliza de seguro, por favor?'],
#  ['¿Puede ayudar con mi póliza de seguro, por favor?',
#   '¿Con qué política puedo ayudarle hoy?'],
#  ['¿Con qué política puedo ayudarle hoy?', 'Mi número de póliza es 879538163'],
#  ['Mi número de póliza es 879538163',
#   'Bien, veo que usted tiene cobertura en el hogar que cubre el fuego y la pérdida debido a los volcanes'],
#  ['Bien, veo que usted tiene cobertura en el hogar que cubre el fuego y la pérdida debido a los volcanes',
#   '¿También cubre los daños causados por el agua?'],
#  ['¿También cubre los daños causados por el agua?',
#   'No hay daños por agua enumerados en esta política. Puedo agregarlo para ti'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Puedes decirme cuánto estoy asegurado?'],
#  ['¿Puedes decirme cuánto estoy asegurado?',
#   'Sí, First Ill necesita saber apellido y número de cuenta/'],
#  ['Sí, First Ill necesita saber apellido y número de cuenta/',
#   'Smith, 123456'],
#  ['Smith, 123456', 'Ok, ¿de qué plan de seguro estás preguntando?'],
#  ['Ok, ¿de qué plan de seguro estás preguntando?',
#   'Mi plan de seguro de vida'],
#  ['Mi plan de seguro de vida', 'Ok, Estás asegurado por $100,000.'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Puedes ayudarme con mi seguro?'],
#  ['¿Puedes ayudarme con mi seguro?', 'De hecho, puedo. ¿Qué necesitas hoy?'],
#  ['De hecho, puedo. ¿Qué necesitas hoy?',
#   '¿Cómo cambiaría los términos de mi póliza de seguro de vida?'],
#  ['¿Cómo cambiaría los términos de mi póliza de seguro de vida?',
#   'Para ello tendrá que ponerse en contacto con su corredor de seguros. ¿Desea información de contacto?'],
#  ['Para ello tendrá que ponerse en contacto con su corredor de seguros. ¿Desea información de contacto?',
#   'Sí, por favor.'],
#  ['Sí, por favor.', '¿Cuál es el nombre de su agente de seguros o corredor?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Quiero saber mi póliza de seguro.'],
#  ['Quiero saber mi póliza de seguro.',
#   'Claro, puedo ayudar con esa política.'],
#  ['Claro, puedo ayudar con esa política.',
#   '¿Mi seguro cubre los daños causados por el agua?'],
#  ['¿Mi seguro cubre los daños causados por el agua?',
#   'Según mis registros, su póliza no cubre los daños causados por el agua.'],
#  ['Según mis registros, su póliza no cubre los daños causados por el agua.',
#   'entonces, ¿qué cubre mi seguro?'],
#  ['entonces, ¿qué cubre mi seguro?', 'Incendios, robos y terremotos.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola, necesito ayuda con mi póliza de seguro.'],
#  ['Hola, necesito ayuda con mi póliza de seguro.', '¿Cómo puedo ayudar?'],
#  ['¿Cómo puedo ayudar?', '¿Cómo presento una reclamación?'],
#  ['¿Cómo presento una reclamación?',
#   'Póngase en contacto con su agente de seguros.'],
#  ['Póngase en contacto con su agente de seguros.', '¿Cuánto es mi deducible?'],
#  ['¿Cuánto es mi deducible?', 'Su deducible es de $500.'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Cuál es tu política?'],
#  ['¿Cuál es tu política?', '¿Qué tipo de política?'],
#  ['¿Qué tipo de política?', 'De la compañía.'],
#  ['De la compañía.', '¿Necesitas saber lo que cubre?'],
#  ['¿Necesitas saber lo que cubre?', 'Hay política actual Sí'],
#  ['Hay política actual Sí', 'Cubre el agua, el fuego y los actos de Dios'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Hola bienvenido a Insurance Pro Life!'],
#  ['Hola bienvenido a Insurance Pro Life!', '¿Cómo puedo ayudarte hoy?'],
#  ['¿Cómo puedo ayudarte hoy?',
#   'Quiero saber si mi seguro cubre los daños causados por el agua'],
#  ['Quiero saber si mi seguro cubre los daños causados por el agua',
#   '¿Cuál es su número de póliza?'],
#  ['¿Cuál es su número de póliza?', '1235558'],
#  ['1235558', 'Parece que no está cubierto por daños causados por el agua.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito información sobre por qué mi política cubre por qué no'],
#  ['Necesito información sobre por qué mi política cubre por qué no',
#   '¿Cuál es su número de póliza?'],
#  ['¿Cuál es su número de póliza?', 'AB8574967'],
#  ['AB8574967',
#   'Bien, parece que tu póliza cubre daños causados por el agua, daños por incendios y actos de Dios.'],
#  ['Bien, parece que tu póliza cubre daños causados por el agua, daños por incendios y actos de Dios.',
#   '¿Qué es un acto de Dios? ¿Como un tornado?'],
#  ['¿Qué es un acto de Dios? ¿Como un tornado?',
#   'Un acto de Dios es considerado un accidente fuera de tu control, como la caída de un árbol.'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Cuál es mi seguro médico?'],
#  ['¿Cuál es mi seguro médico?',
#   'siento decírtelo, pero no tienes un seguro médico'],
#  ['siento decírtelo, pero no tienes un seguro médico', 'Creo que tengo'],
#  ['Creo que tengo', 'Ya lo he comprobado, realmente no tienes'],
#  ['Ya lo he comprobado, realmente no tienes', '¿Puedes comprobarlo de nuevo?'],
#  ['¿Puedes comprobarlo de nuevo?', 'Sí, claro'],
#  ['Hola, ¿en qué puedo ayudarle? Hola',
#   'Hola, ¿puedes ayudar con mi póliza de seguro?'],
#  ['Hola, ¿puedes ayudar con mi póliza de seguro?', 'claro, ¿qué hay de eso?'],
#  ['claro, ¿qué hay de eso?',
#   'Recientemente tuvimos algunos daños por granizo. ¿Está cubierto con mi póliza actual?'],
#  ['Recientemente tuvimos algunos daños por granizo. ¿Está cubierto con mi póliza actual?',
#   'Déjame comprobarte eso, ¿en qué compañía estás?'],
#  ['Déjame comprobarte eso, ¿en qué compañía estás?',
#   'Estoy con Acme Incorporated.'],
#  ['Estoy con Acme Incorporated.', 'Ok, voy a comprobar eso para ti'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito información sobre mi póliza de seguro.'],
#  ['Necesito información sobre mi póliza de seguro.', 'bien gp por delante'],
#  ['bien gp por delante', '¿Mi póliza cubre los daños causados por el agua?'],
# ...
#   'cubre los daños causados por el agua'],
#  ['cubre los daños causados por el agua',
#   'No, su póliza no cubre los daños causados por el agua.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito saber lo que cubre mi política actual.'],
#  ['Necesito saber lo que cubre mi política actual.', 'su cuenta #?'],
#  ['su cuenta #?', '3561561651'],
#  ['3561561651', 'cubre el agua, el fuego, los actos de Dios'],
#  ['cubre el agua, el fuego, los actos de Dios',
#   'Bien, ¿un acto de Dios cubriría un tornado?'],
#  ['Bien, ¿un acto de Dios cubriría un tornado?', 'Sí'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo una cuenta de seguro contigo y necesito averiguar algo.'],
#  ['Tengo una cuenta de seguro contigo y necesito averiguar algo.',
#   '¿Qué tipo de plan tienes?'],
#  ['¿Qué tipo de plan tienes?', 'seguro de vida'],
#  ['seguro de vida', 'Hay varias opciones. ¿Sabes el nombre?'],
#  ['Hay varias opciones. ¿Sabes el nombre?',
#   'Seguro de vida de Mary. ¿Cuánto estoy asegurado?'],
#  ['Seguro de vida de Mary. ¿Cuánto estoy asegurado?',
#   '¿Fue por la cobertura de oro o plata?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Necesito ayuda con mi seguro, por favor'],
#  ['Necesito ayuda con mi seguro, por favor',
#   '¡Puedo ayudar con eso! Pero primero, ¿puedo tener su número de cuenta, por favor?'],
#  ['¡Puedo ayudar con eso! Pero primero, ¿puedo tener su número de cuenta, por favor?',
#   'Por supuesto, es 7145283'],
#  ['Por supuesto, es 7145283',
#   'Ok, he recogido tu información. ¿Qué tipo de ayuda necesitabas?'],
#  ['Ok, he recogido tu información. ¿Qué tipo de ayuda necesitabas?',
#   'Sólo quería saber lo que cubre mi póliza de hogar'],
#  ['Sólo quería saber lo que cubre mi póliza de hogar',
#   'Su póliza de seguro de hogar cubre los daños causados por el agua, el fuego y los actos de Dios.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Quiero saber cómo puedo cambiar los términos de mi póliza de seguro de vida.'],
#  ['Quiero saber cómo puedo cambiar los términos de mi póliza de seguro de vida.',
#   'No puedo darte esa información.'],
#  ['No puedo darte esa información.', '¿Por qué no?'],
#  ['¿Por qué no?',
#   'Para esa información es necesario hacer una cita con un corredor de seguros'],
#  ['Para esa información es necesario hacer una cita con un corredor de seguros',
#   'oh. Bueno, ¿cómo hago eso?'],
#  ['oh. Bueno, ¿cómo hago eso?',
#   'En el sitio web vaya a la sección de contacto y rellene el formulario de cita de solicitud'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puedes ayudarme sobre la póliza de seguro?'],
#  ['¿Puedes ayudarme sobre la póliza de seguro?',
#   '¡Claro! ¿Con qué se trata nuestra póliza de seguro con la que necesita ayuda?'],
#  ['¡Claro! ¿Con qué se trata nuestra póliza de seguro con la que necesita ayuda?',
#   'Sí. Quiero cambiar algunos términos de mi póliza de seguro de vida.'],
#  ['Sí. Quiero cambiar algunos términos de mi póliza de seguro de vida.',
#   'Podemos ayudar con eso, pero usted tiene que programar una cita con nuestro corredor de seguros.'],
#  ['Podemos ayudar con eso, pero usted tiene que programar una cita con nuestro corredor de seguros.',
#   'Bien. Gracias por la información. Fijaré una cita con su corredor mañana a las 9 a. m.'],
#  ['Bien. Gracias por la información. Fijaré una cita con su corredor mañana a las 9 a. m.',
#   'Bien, te he reservado para mañana a las 9 am.'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Puedes ayudarme con mi póliza?'],
#  ['¿Puedes ayudarme con mi póliza?', '¿Cuál es su número de póliza?'],
#  ['¿Cuál es su número de póliza?', '598623584'],
#  ['598623584', '¿Y qué le gustaría saber sobre su cobertura?'],
#  ['¿Y qué le gustaría saber sobre su cobertura?',
#   '¿Cómo puedo cambiar los términos de mi póliza de seguro de vida?'],
#  ['¿Cómo puedo cambiar los términos de mi póliza de seguro de vida?',
#   'Con el fin de cambiar los términos de su póliza de seguro de vida tendrá que hablar con un corredor de seguros'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi seguro'],
#  ['Tengo una pregunta sobre mi seguro', '¿Tiene su número de póliza?'],
#  ['¿Tiene su número de póliza?', '32546463746'],
#  ['32546463746', 'Bien, tengo tu información. ¿Qué te gustaría saber?'],
#  ['Bien, tengo tu información. ¿Qué te gustaría saber?',
#   'En mi seguro de coche, ¿mis tarifas subirán pronto?'],
#  ['En mi seguro de coche, ¿mis tarifas subirán pronto?',
#   'Sus tarifas no cambiarán hasta el final del período de política el 15 de octubre. Unos 30 días antes debe recibir notificación de cualquier cambio.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo algunas preguntas sobre mi póliza de seguro'],
#  ['Tengo algunas preguntas sobre mi póliza de seguro', '¿cómo puedo ayudar'],
#  ['¿cómo puedo ayudar',
#   'Necesito saber si mi póliza cubre los daños causados por el viento'],
#  ['Necesito saber si mi póliza cubre los daños causados por el viento',
#   'no, no lo hace'],
#  ['no, no lo hace', '¿Tiene mi número de póliza?'],
#  ['¿Tiene mi número de póliza?', 'tengo 557839020294'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Necesito ayuda, ¿puedes ayudarme?'],
#  ['Necesito ayuda, ¿puedes ayudarme?', 'seguro'],
#  ['seguro', '¿Quiero un seguro?'],
#  ['¿Quiero un seguro?', '¿Qué tipo de seguro?'],
#  ['¿Qué tipo de seguro?', 'Heath i]nsurance'],
#  ['Heath i]nsurance', 'Bien'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo un seguro questio'],
#  ['Tengo un seguro questio',
#   'Estoy diseñado para ayudar con las preguntas del seguro.'],
#  ['Estoy diseñado para ayudar con las preguntas del seguro.',
#   '¿Qué tipo de cobertura de vehículos tengo?'],
#  ['¿Qué tipo de cobertura de vehículos tengo?',
#   '¿Puedes decirme tu número de póliza?'],
#  ['¿Puedes decirme tu número de póliza?', '12345'],
#  ['12345',
#   'Tiene cobertura completa, nuestro paquete de seguro de primera línea.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola. Tengo algunas preguntas sobre mi política'],
#  ['Hola. Tengo algunas preguntas sobre mi política', 'Ok, puedo ayudar'],
#  ['Ok, puedo ayudar',
#   'Gracias ¿Mi póliza de seguro actual cubre los daños causados por el agua?'],
#  ['Gracias ¿Mi póliza de seguro actual cubre los daños causados por el agua?',
#   '¿Puedo tener su número de póliza?'],
#  ['¿Puedo tener su número de póliza?', 'El número es 009-129-12123'],
#  ['El número es 009-129-12123',
#   'Ok, su póliza no cubre los daños causados por el agua.'],
#  ['Hola, ¿en qué puedo ayudarle? eh',
#   'Tengo una pregunta sobre mi póliza de seguro médico'],
#  ['Tengo una pregunta sobre mi póliza de seguro médico', 'ok seguir adelante'],
#  ['ok seguir adelante',
#   'Deja que te dé mi número de póliza primero sólo para comer o seguro que estamos en la misma página. Es 256898045'],
#  ['Deja que te dé mi número de póliza primero sólo para comer o seguro que estamos en la misma página. Es 256898045',
#   'Bien'],
#  ['Bien', '¿Puedes ver mi prima de seguro y decirme qué es?'],
#  ['¿Puedes ver mi prima de seguro y decirme qué es?',
#   'según la comprobación, actualmente no tiene plan insu de salud'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi política'],
#  ['Tengo una pregunta sobre mi política', 'Claro, ¿qué te gustaría saber?'],
#  ['Claro, ¿qué te gustaría saber?',
#   'Si mi póliza cubre los daños causados por el agua, ¿necesita el número de póliza?'],
#  ['Si mi póliza cubre los daños causados por el agua, ¿necesita el número de póliza?',
#   'Sí, por favor confirme su número de póliza para mí.'],
#  ['Sí, por favor confirme su número de póliza para mí.', '23215'],
#  ['23215', 'Veo que su póliza no cubre los daños causados por el agua.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Necesito ayuda con mi seguro.'],
#  ['Necesito ayuda con mi seguro.',
#   'Seguro que lo primero que necesito para empezar es su número de póliza'],
#  ['Seguro que lo primero que necesito para empezar es su número de póliza',
#   'AS7778 Quiero cambiar mi deducible.'],
#  ['AS7778 Quiero cambiar mi deducible.',
#   'Actualmente son 5000 ¿a qué quieres cambiarlo?'],
#  ['Actualmente son 5000 ¿a qué quieres cambiarlo?', '$500'],
#  ['$500', 'Bien, eso será $112 extra'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola, me gustaría obtener información en vivo sobre mi política actual'],
#  ['Hola, me gustaría obtener información en vivo sobre mi política actual',
#   'Claro, ¿qué te gustaría saber?'],
#  ['Claro, ¿qué te gustaría saber?',
#   '¿Me gustaría saber lo que cubre mi póliza?'],
#  ['¿Me gustaría saber lo que cubre mi póliza?',
#   'La política actual cubre los daños causados por el agua, el fuego y los actos de Dios.'],
#  ['La política actual cubre los daños causados por el agua, el fuego y los actos de Dios.',
#   '¿Qué constituye los actos de Dios?'],
#  ['¿Qué constituye los actos de Dios?',
#   'Cualquier cosa causada por fuerzas naturales como tornados, terremotos, huracanes, etc.'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Cuánto estoy cubierto?'],
#  ['¿Cuánto estoy cubierto?', '¿Qué plan de seguro está preguntando?'],
#  ['¿Qué plan de seguro está preguntando?', 'mina.'],
#  ['mina.', 'qué plan de seguro por favor'],
#  ['qué plan de seguro por favor', 'Salud'],
#  ['Salud', 'Bien, tienes $20,000 en seguro médico'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Es bueno con las pólizas de seguro?'],
#  ['¿Es bueno con las pólizas de seguro?',
#   'Sí, represento a su compañía de seguros.'],
#  ['Sí, represento a su compañía de seguros.',
#   'Tuve un accidente ¿sabes si el seguro cubre los daños causados por el agua a mi casa?'],
#  ['Tuve un accidente ¿sabes si el seguro cubre los daños causados por el agua a mi casa?',
#   'Por favor, proporcione más detalles de la cuenta que necesito su número de cuenta y los últimos dos dígitos de su dirección de casa'],
#  ['Por favor, proporcione más detalles de la cuenta que necesito su número de cuenta y los últimos dos dígitos de su dirección de casa',
#   'la tubería fue volada por una cuenta de tormenta es 123456'],
#  ['la tubería fue volada por una cuenta de tormenta es 123456',
#   'Bien, veo la cuenta.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'hola puedes ayudarme con mi seguro médico'],
#  ['hola puedes ayudarme con mi seguro médico', '¿Con qué necesitas ayuda?'],
#  ['¿Con qué necesitas ayuda?',
#   '¿Puedes decirme cuál es mi prima de seguro médico?'],
#  ['¿Puedes decirme cuál es mi prima de seguro médico?',
#   'Parece que actualmente no tienes un plan con nosotros.'],
#  ['Parece que actualmente no tienes un plan con nosotros.',
#   '¿No? ¿Puedes volver a comprobarlo?'],
#  ['¿No? ¿Puedes volver a comprobarlo?',
#   'Sí, parece que tu plan expiró. ¿Te gustaría renovar?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puedes ayudarme con mi póliza de seguro?'],
#  ['¿Puedes ayudarme con mi póliza de seguro?',
#   '¡Desde luego, puedo ayudarte con tu política! ¿Cuál es su número'],
#  ['¡Desde luego, puedo ayudarte con tu política! ¿Cuál es su número',
#   'El número de póliza es 34828423'],
#  ['El número de póliza es 34828423',
#   'Genial, tirando de eso ahora. ¿Qué le gustaría saber sobre su política'],
#  ['Genial, tirando de eso ahora. ¿Qué le gustaría saber sobre su política',
#   'Sólo quiero saber si mi póliza actualmente cubre los daños causados por el agua'],
#  ['Sólo quiero saber si mi póliza actualmente cubre los daños causados por el agua',
#   'Hm, no. arrepentido. Parece que su póliza no cubre los daños causados por el agua'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo una pregunta sobre mi póliza de seguro. ¿Puedes ayudar?'],
#  ['Tengo una pregunta sobre mi póliza de seguro. ¿Puedes ayudar?',
#   'Sí, ¿cuál es la pregunta?'],
#  ['Sí, ¿cuál es la pregunta?', '¿Qué cubre mi póliza actual?'],
#  ['¿Qué cubre mi póliza actual?',
#   'Su política actual cubre los daños causados por el agua, el fuego y los actos de Dios'],
#  ['Su política actual cubre los daños causados por el agua, el fuego y los actos de Dios',
#   'Bien, gracias por la información.'],
#  ['Bien, gracias por la información.',
#   'De nada. ¿Qué más puedo hacer por ti?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Me gustaría tener información sobre mi seguro, por favor.'],
#  ['Me gustaría tener información sobre mi seguro, por favor.',
#   '¡hola! ¿En qué puedo ayudar?'],
#  ['¡hola! ¿En qué puedo ayudar?',
#   'Me gustaría saber cuánto estoy asegurado para'],
#  ['Me gustaría saber cuánto estoy asegurado para', 'seguro. comprobación...'],
#  ['seguro. comprobación...', 'gracias'],
#  ['gracias',
#   'Encontré varias pólizas de seguro. ¿Puede especificar qué directiva le gustaría conocer?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola me gustaría saber cuál es mi prima de seguro por favor?'],
#  ['Hola me gustaría saber cuál es mi prima de seguro por favor?',
#   '¿Puedo tener el nombre en la póliza?'],
#  ['¿Puedo tener el nombre en la póliza?', 'Sí, su Bill Nye'],
#  ['Sí, su Bill Nye', 'Sólo un momento mientras comprueba'],
#  ['Sólo un momento mientras comprueba', 'gracias'],
#  ['gracias',
#   'No estoy mostrando un plan de seguro con ese nombre, ¿hay otro nombre?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puedo obtener información sobre mi seguro médico?'],
#  ['¿Puedo obtener información sobre mi seguro médico?',
#   'seguro. ¿cómo puedo ayudar?'],
#  ['seguro. ¿cómo puedo ayudar?', '¿Cuál es mi prima'],
#  ['¿Cuál es mi prima', '¿Puedo tener tu número de cuenta primero, por favor?'],
#  ['¿Puedo tener tu número de cuenta primero, por favor?', 'Es 73437111'],
#  ['Es 73437111',
#   'Lamento que su seguro se cancele actualmente debido al impago'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Me gustaría obtener información sobre mi póliza de seguro'],
#  ['Me gustaría obtener información sobre mi póliza de seguro',
#   'Seguro sobre ?'],
#  ['Seguro sobre ?',
#   'Mi póliza de seguro de hogar, por favor. Me gustaría saber si cubre los daños causados por el agua.'],
#  ['Mi póliza de seguro de hogar, por favor. Me gustaría saber si cubre los daños causados por el agua.',
#   'Su póliza de seguro no cubre los daños causados por el agua'],
#  ['Su póliza de seguro no cubre los daños causados por el agua',
#   'Eso es desafortunado. ¿Cuánto sería añadirlo?'],
#  ['Eso es desafortunado. ¿Cuánto sería añadirlo?', '$1000'],
#  ['Hola, ¿en qué puedo ayudarle?', 'ayúdame con las cosas del seguro'],
#  ['ayúdame con las cosas del seguro',
#   'Estoy diseñado para ayudarte con el seguro. ¿Con qué quieres ayuda?'],
#  ['Estoy diseñado para ayudarte con el seguro. ¿Con qué quieres ayuda?',
#   'Descubrí que no me muero y quiero cambiar los términos de mi seguro de vida'],
#  ['Descubrí que no me muero y quiero cambiar los términos de mi seguro de vida',
#   'Para cambiar los términos de su seguro, tendría que hablar con su corredor de seguros. ¿Le gustaría hacer una cita con su corredor?'],
#  ['Para cambiar los términos de su seguro, tendría que hablar con su corredor de seguros. ¿Le gustaría hacer una cita con su corredor?',
#   'Sí, configurarlo'],
#  ['Sí, configurarlo',
#   'Tu agente es Jimmy Frank. Está disponible el martes a las 2:30 p. m., ¿eso funciona para usted?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'hola'],
#  ['hola', '¿Cómo puedo ayudarle con su seguro hoy?'],
#  ['¿Cómo puedo ayudarle con su seguro hoy?',
#   '¿Quiero saber si mi póliza cubre los daños causados por el agua?'],
#  ['¿Quiero saber si mi póliza cubre los daños causados por el agua?',
#   'Grande ¿Cuál es su número de política'],
#  ['Grande ¿Cuál es su número de política', 'su 91837475'],
#  ['su 91837475',
#   'Está bien, déjame comprobarlo. Parece que su póliza no cubre los daños causados por el agua'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito información sobre mi plan de salud.'],
#  ['Necesito información sobre mi plan de salud.',
#   'Lo siento, pero actualmente no tiene un plan de seguro médico.'],
#  ['Lo siento, pero actualmente no tiene un plan de seguro médico.',
#   '¿No? ¿Es la compañía de seguros Cahill?'],
#  ['¿No? ¿Es la compañía de seguros Cahill?',
#   'Su seguro fue cancelado por su empleador el 25 de abril.'],
#  ['Su seguro fue cancelado por su empleador el 25 de abril.',
#   '¿Qué? ¿por qué?'],
#  ['¿Qué? ¿por qué?',
#   'No sé por qué su empleador canceló su seguro médico. Es posible que desee ponerse en contacto con su empleador.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puedes conseguirme el número de teléfono de dominó?'],
#  ...]

# %% [markdown]
# ## Extracción del dataset Dailyd en pares

# %%
## nombre base del dataset DAILYD
dailyd_archivo = "DAILYD_translation_es2en.csv"

data = os.path.join("./DAILYD_METALW", dailyd_archivo)

conversaciones = cargarLinea(data, campos)
pares_conversaciones += pares(conversaciones)

# %%
pares_conversaciones
# Out:
# [['Hola, ¿en qué puedo ayudarle?', 'Sí'],
#  ['Sí', '¿Cómo puedo ser de ayuda?'],
#  ['¿Cómo puedo ser de ayuda?', 'Quiero saber sobre la política que tengo'],
#  ['Quiero saber sobre la política que tengo',
#   'Bien, ¿puedo conseguir tu nombre, por favor?'],
#  ['Bien, ¿puedo conseguir tu nombre, por favor?',
#   '¿Cubre los daños causados por el agua?'],
#  ['¿Cubre los daños causados por el agua?',
#   'Necesito su nombre y número de póliza para acceder a su póliza, por favor.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi política'],
#  ['Tengo una pregunta sobre mi política',
#   'seguro. ¿Puedes decirme tu número de póliza?'],
#  ['seguro. ¿Puedes decirme tu número de póliza?', '3425512'],
#  ['3425512', 'Bien, tengo tu póliza aquí. ¿Cuál es tu pregunta?'],
#  ['Bien, tengo tu póliza aquí. ¿Cuál es tu pregunta?',
#   'cubre los daños causados por el agua?'],
#  ['cubre los daños causados por el agua?',
#   'Esta política no cubre los daños causados por el agua.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Hola'],
#  ['Hola', 'hola'],
#  ['hola', 'Me gustaría tener algunas consultas'],
#  ['Me gustaría tener algunas consultas', '¿en qué puedo ayudarle? De acuerdo'],
#  ['¿en qué puedo ayudarle? De acuerdo',
#   'así que estoy tratando de comprobar con respecto a mi seguro'],
#  ['así que estoy tratando de comprobar con respecto a mi seguro',
#   'la política actual cubre los daños causados por el agua, el fuego y los actos de Dios?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'hola. Necesito ayuda con mi seguro'],
#  ['hola. Necesito ayuda con mi seguro',
#   'Claro, ¿cuál es tu número de póliza?'],
#  ['Claro, ¿cuál es tu número de póliza?', '5642394'],
#  ['5642394', 'Está bien, se ha detenido. ¿Qué puedo responder por usted?'],
#  ['Está bien, se ha detenido. ¿Qué puedo responder por usted?',
#   '¿Cómo cambio los términos de mi póliza de seguro de vida?'],
#  ['¿Cómo cambio los términos de mi póliza de seguro de vida?',
#   'Puedo cambiarlos por ti. ¿Qué te gustaría cambiar? A menos que sea información más detallada, entonces usted tendrá que hacer una cita con su corredor de seguros'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Me gustaría encontrar información sobre mi seguro.'],
#  ['Me gustaría encontrar información sobre mi seguro.',
#   'Me gustaría ayudarle con ese plan de seguro al que se refiere?'],
#  ['Me gustaría ayudarle con ese plan de seguro al que se refiere?',
#   'Mi plan de seguro de vida.'],
#  ['Mi plan de seguro de vida.',
#   '¿Me permites el número de póliza, por favor?'],
#  ['¿Me permites el número de póliza, por favor?', '2387782786'],
#  ['2387782786', 'Gracias. ¿Qué información puedo ofrecerle?'],
#  ['Gracias. ¿Qué información puedo ofrecerle?', '¿Cuánto estoy asegurado?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi política'],
#  ['Tengo una pregunta sobre mi política', '¿Qué es?'],
#  ['¿Qué es?', '¿Mi póliza cubre los daños causados por el agua?'],
#  ['¿Mi póliza cubre los daños causados por el agua?',
#   'por favor, espere mientras reviso su cobertura de daños por agua'],
#  ['por favor, espere mientras reviso su cobertura de daños por agua',
#   '¿Necesita mi número de póliza?'],
#  ['¿Necesita mi número de póliza?',
#   'al comprobar, cubre a su dama de agua en nuestra política'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puedes responder a una pregunta de seguro por mí?'],
#  ['¿Puedes responder a una pregunta de seguro por mí?',
#   'Sí, puedo. ¿Qué quieres saber?'],
#  ['Sí, puedo. ¿Qué quieres saber?',
#   '¿Me gustaría saber si la póliza de seguro típica del propietario cubre los daños causados por tornados?'],
#  ['¿Me gustaría saber si la póliza de seguro típica del propietario cubre los daños causados por tornados?',
#   'Sí, lo hace.'],
#  ['Sí, lo hace.',
#   '¿También cubre normalmente los daños causados por las inundaciones?'],
#  ['¿También cubre normalmente los daños causados por las inundaciones?',
#   'Sí, así como otros desastres naturales de naturaleza similar.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito información sobre mi seguro de propietarios'],
#  ['Necesito información sobre mi seguro de propietarios',
#   'Claro, ¿puedo obtener tu número de póliza, por favor?'],
#  ['Claro, ¿puedo obtener tu número de póliza, por favor?', '789406'],
#  ['789406', 'Está bien, tengo eso aquí. ¿Qué información necesitabas?'],
#  ['Está bien, tengo eso aquí. ¿Qué información necesitabas?',
#   '¿Cuál es mi deducción?'],
#  ['¿Cuál es mi deducción?',
#   'El deducible de su seguro de hogar es de 10,000$'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Puedes ayudarme con mi seguro?'],
#  ['¿Puedes ayudarme con mi seguro?', 'Claro. ¿Qué puedo hacer por ti hoy?'],
#  ['Claro. ¿Qué puedo hacer por ti hoy?',
#   'Quiero comprobar y ver cuál es mi deducible actual para mi seguro de automóvil'],
#  ['Quiero comprobar y ver cuál es mi deducible actual para mi seguro de automóvil',
#   '¿Puedo tener su número de póliza?'],
#  ['¿Puedo tener su número de póliza?',
#   'Claro, el número de póliza es 57348175834'],
#  ['Claro, el número de póliza es 57348175834', 'Tienes un deducible de $500.'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Puedes ayudar?'],
#  ['¿Puedes ayudar?', 'Sí, ¿qué es lo que necesitas?'],
#  ['Sí, ¿qué es lo que necesitas?', 'Necesito información sobre mi póliza.'],
#  ['Necesito información sobre mi póliza.',
#   'Claro que puedo ayudarte con eso sólo dame tu número de póliza'],
#  ['Claro que puedo ayudarte con eso sólo dame tu número de póliza',
#   '¿Dónde puedo encontrar eso?'],
#  ['¿Dónde puedo encontrar eso?', 'Debería estar en tu cuenta'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Hola'],
#  ['Hola', '¿cómo puedo ayudar?'],
#  ['¿cómo puedo ayudar?', 'compañía de seguros me ayudan'],
#  ['compañía de seguros me ayudan', 'qué seguro quieres'],
#  ['qué seguro quieres', '¿Cubre el agua? eh'],
#  ['¿Cubre el agua? eh',
#   'lo siento, pero triste decir que no cubra los daños causados por el agua'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'hola necesita saber algo acerca de mi póliza de seguro'],
#  ['hola necesita saber algo acerca de mi póliza de seguro',
#   '¿Seguro qué necesitas saber? Me encantaría ayudar.'],
#  ['¿Seguro qué necesitas saber? Me encantaría ayudar.',
#   '¿Mi póliza cubre los daños causados por el agua?'],
#  ['¿Mi póliza cubre los daños causados por el agua?',
#   'Desafortunadamente, no lo hace.'],
#  ['Desafortunadamente, no lo hace.',
#   'ok, ¿qué pasa con los daños causados por el fuego?'],
#  ['ok, ¿qué pasa con los daños causados por el fuego?',
#   'Sí. Los daños causados por el fuego están cubiertos'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi política.'],
#  ['Tengo una pregunta sobre mi política.',
#   'Claro, ¿qué le gustaría saber sobre su política?'],
#  ['Claro, ¿qué le gustaría saber sobre su política?',
#   '¿Cubre los daños causados por el agua?'],
#  ['¿Cubre los daños causados por el agua?',
#   'Déjame echar un vistazo. Aquí dice que su póliza no cubre los daños causados por el agua.'],
#  ['Déjame echar un vistazo. Aquí dice que su póliza no cubre los daños causados por el agua.',
#   '¿Puedo agregarlo a mi póliza?'],
#  ['¿Puedo agregarlo a mi póliza?',
#   'Puede hacerlo, pero debe tener en cuenta que cualquier reclamación de seguro en condiciones de "daños causados por el agua" no estará cubierta si los daños causados por el agua ocurrieron antes de actualizar su póliza.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'ayúdame con el seguro'],
#  ['ayúdame con el seguro',
#   'De acuerdo. ¿qué política está preguntando acerca de'],
#  ['De acuerdo. ¿qué política está preguntando acerca de',
#   'para mi seguro de barco'],
#  ['para mi seguro de barco',
#   'De acuerdo. ¿Con qué puedo ayudarle con respecto a su seguro de barco'],
#  ['De acuerdo. ¿Con qué puedo ayudarle con respecto a su seguro de barco',
#   '¿Cuánto estoy asegurado?'],
#  ['¿Cuánto estoy asegurado?', 'usted está asegurado por 50.000'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi política.'],
#  ['Tengo una pregunta sobre mi política.', 'Claro. ¿Qué te gustaría saber?'],
#  ['Claro. ¿Qué te gustaría saber?', '¿Qué cubre?'],
#  ['¿Qué cubre?',
#   'Su política actual cubre los daños causados por el agua, el fuego y los actos de Dios.'],
#  ['Su política actual cubre los daños causados por el agua, el fuego y los actos de Dios.',
#   'En mi casa.'],
#  ['En mi casa.', 'Sí, en tu casa.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Sí, necesito ayuda con mi póliza.'],
#  ['Sí, necesito ayuda con mi póliza.', 'seguro. ¿Qué necesitas?'],
#  ['seguro. ¿Qué necesitas?',
#   'Sólo necesito conocer algunas coberturas de políticas. ¿Puedes ayudar con eso?'],
#  ['Sólo necesito conocer algunas coberturas de políticas. ¿Puedes ayudar con eso?',
#   'Sí, puedo ayudar.'],
#  ['Sí, puedo ayudar.', '¿Mi póliza cubre los daños causados por el agua?'],
#  ['¿Mi póliza cubre los daños causados por el agua?',
#   '¿Cuál es su número de póliza?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'necesita algo de información'],
#  ['necesita algo de información', '¿De qué tipo?'],
#  ['¿De qué tipo?', '¿Tienes mi cuenta arriba?'],
#  ['¿Tienes mi cuenta arriba?', 'Sí'],
#  ['Sí', '¿Cuál es mi prima de seguro médico?'],
#  ['¿Cuál es mi prima de seguro médico?', 'Sus 5 dólares al mes'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo una pregunta sobre mi póliza de seguro.'],
#  ['Tengo una pregunta sobre mi póliza de seguro.',
#   'Claro, puedo ayudarte con preguntas sobre tu polocy de seguro ¿qué te gustaría saber?'],
#  ['Claro, puedo ayudarte con preguntas sobre tu polocy de seguro ¿qué te gustaría saber?',
#   '¿Qué cubre mi póliza actual?'],
#  ['¿Qué cubre mi póliza actual?',
#   'Bien, permítanme buscar información sobre lo que cubre su política actual..... Su política actual cubre los daños causados por el agua, el fuego y los actos de Dios'],
#  ['Bien, permítanme buscar información sobre lo que cubre su política actual..... Su política actual cubre los daños causados por el agua, el fuego y los actos de Dios',
#   '¿El agua es igual que las inundaciones o las inundaciones no están cubiertas?'],
#  ['¿El agua es igual que las inundaciones o las inundaciones no están cubiertas?',
#   'Las inundaciones están cubiertas'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Qué seguro médico tenemos?'],
#  ['¿Qué seguro médico tenemos?', 'no tenemos un seguro médico'],
#  ['no tenemos un seguro médico', '¿Es pemio?'],
#  ['¿Es pemio?', 'Siento no entender la pregunta'],
#  ['Siento no entender la pregunta', '¿Qué tenemos?'],
#  ['¿Qué tenemos?', 'la compañía tiene Aetna y Kaiser'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Quiero saber sobre política'],
#  ['Quiero saber sobre política',
#   'Claro, puedo ayudarte con las pólizas de seguro.'],
#  ['Claro, puedo ayudarte con las pólizas de seguro.',
#   '¿Tienes mi cuenta levantada?'],
#  ['¿Tienes mi cuenta levantada?',
#   'Tengo la información que se guardó automáticamente de lo que se introdujo.'],
#  ['Tengo la información que se guardó automáticamente de lo que se introdujo.',
#   'cubre los daños causados por el agua?'],
#  ['cubre los daños causados por el agua?',
#   'Un momento por favor mientras lo compruedo para usted [ . . . ] Desafortunadamente, su póliza de seguro no cubre los daños causados por el agua.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola me gustaría saber cuánto estoy asegurado para hoy'],
#  ['Hola me gustaría saber cuánto estoy asegurado para hoy',
#   'Sí. ¿Qué quieres decir con/.?'],
#  ['Sí. ¿Qué quieres decir con/.?',
#   'Veo que usted es un bot que representa a mi compañía de seguros me gustaría saber cuánto estoy asegurado para'],
#  ['Veo que usted es un bot que representa a mi compañía de seguros me gustaría saber cuánto estoy asegurado para',
#   'Tu asegurado para todo. En cuanto a lo que he comprobado su cuenta todo estaba asegurado para su.'],
#  ['Tu asegurado para todo. En cuanto a lo que he comprobado su cuenta todo estaba asegurado para su.',
#   'Bien perfecto'],
#  ['Bien perfecto', '¿Todavía estás ahí?\\ ¿Hay algo más?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puedes ayudarme a averiguar algunas cosas sobre mi seguro?'],
#  ['¿Puedes ayudarme a averiguar algunas cosas sobre mi seguro?',
#   'Sí, puedo ayudar con eso.'],
#  ['Sí, puedo ayudar con eso.',
#   'Ok mi póliza es 238393483648946334986 Necesito saber cuánto estoy asegurado para'],
#  ['Ok mi póliza es 238393483648946334986 Necesito saber cuánto estoy asegurado para',
#   'Ok, ¿de qué plan de seguro estás preguntando?'],
#  ['Ok, ¿de qué plan de seguro estás preguntando?', 'Mi motocicleta'],
#  ['Mi motocicleta',
#   'Ok, usted tiene $15,000 en responsabilidad. y $20,000 en medicina.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Quiero saber si mi póliza cubre los daños causados por el agua. Mi número de póliza es 1234567890.'],
#  ['Quiero saber si mi póliza cubre los daños causados por el agua. Mi número de póliza es 1234567890.',
#   'Por supuesto, déjame comprobarlo. No, no parece que su póliza cubra los daños causados por el agua'],
#  ['Por supuesto, déjame comprobarlo. No, no parece que su póliza cubra los daños causados por el agua',
#   '¿Qué cubre entonces?'],
#  ['¿Qué cubre entonces?',
#   'Su política cubre sólo el agua, el fuego y los actos de Dios'],
#  ['Su política cubre sólo el agua, el fuego y los actos de Dios',
#   '¿Los daños causados por el agua no están incluidos bajo el agua?'],
#  ['¿Los daños causados por el agua no están incluidos bajo el agua?',
#   'Lo siento. Debe haber habido un error. Su política sólo incluye fuego y actos de dios'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo preguntas sobre política'],
#  ['Tengo preguntas sobre política',
#   'Ciertamente, ¿cuál es su número de póliza'],
#  ['Ciertamente, ¿cuál es su número de póliza', '21412489'],
#  ['21412489', 'Está bien, déjame buscar eso. ¿Cuál es su pregunta'],
#  ['Está bien, déjame buscar eso. ¿Cuál es su pregunta',
#   '¿qué cubre mi póliza actual?'],
#  ['¿qué cubre mi póliza actual?',
#   'Su política cubre los daños causados por el agua, el fuego y los actos de Dios'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi seguro'],
#  ['Tengo una pregunta sobre mi seguro',
#   'Puedo ayudar con eso. ¿Cuál es tu pregunta?'],
#  ['Puedo ayudar con eso. ¿Cuál es tu pregunta?',
#   '¿puede decirme lo que mi política cubre'],
#  ['¿puede decirme lo que mi política cubre',
#   'Puedo hacer eso. Necesitaré tu número de póliza'],
#  ['Puedo hacer eso. Necesitaré tu número de póliza', 'K87657'],
#  ['K87657',
#   'Bien, su póliza proporciona cobertura para los daños causados por el agua, el fuego y los actos de Dios'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo una pregunta sobre mi póliza de seguro'],
#  ['Tengo una pregunta sobre mi póliza de seguro',
#   '¿De qué plan de seguro estás hablando?'],
#  ['¿De qué plan de seguro estás hablando?',
#   'Me refiero a mi póliza de seguro de vida'],
#  ['Me refiero a mi póliza de seguro de vida', 'Bien. ¿Qué te gustaría saber?'],
#  ['Bien. ¿Qué te gustaría saber?', '¿Cuánto estoy asegurado para'],
#  ['¿Cuánto estoy asegurado para', '$250,000'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Tengo una pregunta rápida sobre mi seguridad?'],
#  ['¿Tengo una pregunta rápida sobre mi seguridad?', 'Sí, por favor, adelante'],
#  ['Sí, por favor, adelante',
#   'Me preguntaba cuánto estoy asegurado por incaso de un accidente'],
#  ['Me preguntaba cuánto estoy asegurado por incaso de un accidente',
#   '¿Qué plan estás pidiendo?'],
#  ['¿Qué plan estás pidiendo?', 'Mi seguro de coche'],
#  ['Mi seguro de coche', 'usted está cubierto hasta $10,000'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi política'],
#  ['Tengo una pregunta sobre mi política',
#   '¿Puedo obtener su nombre y número de póliza, por favor?'],
#  ['¿Puedo obtener su nombre y número de póliza, por favor?',
#   'Elroy Bink, 1256'],
#  ['Elroy Bink, 1256', 'Genial, señor Bink. ¿De qué necesitas información>?'],
#  ['Genial, señor Bink. ¿De qué necesitas información>?',
#   '¿Mi póliza cubre los daños causados por el agua?'],
#  ['¿Mi póliza cubre los daños causados por el agua?',
#   'Lo siento, la política actual no cubre los daños causados por el agua. ¿Te gustaría añadirlo hoy?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito información sobre mi póliza de seguro.'],
#  ['Necesito información sobre mi póliza de seguro.',
#   'Ciertamente puedo ayudar con eso. ¿Puedo tener su número de póliza?'],
#  ['Ciertamente puedo ayudar con eso. ¿Puedo tener su número de póliza?',
#   '#353535353'],
#  ['#353535353', '¿Qué información necesita con respecto a su póliza?'],
#  ['¿Qué información necesita con respecto a su póliza?',
#   '¿Cuánto estoy asegurado?'],
#  ['¿Cuánto estoy asegurado?', '¿Qué plan exacto está preguntando hoy?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola, me gustaría su ayuda con mi política'],
#  ['Hola, me gustaría su ayuda con mi política',
#   'Claro, puedo ayudarte con tu póliza de seguro ¿qué te gustaría saber?'],
#  ['Claro, puedo ayudarte con tu póliza de seguro ¿qué te gustaría saber?',
#   'Me pregunto cómo puedo cambiar los términos de mi póliza de seguro de vida. ¿Es algo con lo que puedes ayudarme?'],
#  ['Me pregunto cómo puedo cambiar los términos de mi póliza de seguro de vida. ¿Es algo con lo que puedes ayudarme?',
#   'Si desea cambiar sus términos de seguro de vida tendrá que hacer una cita con nuestro corredor de seguros'],
#  ['Si desea cambiar sus términos de seguro de vida tendrá que hacer una cita con nuestro corredor de seguros',
#   '¿Así que no hay forma de que pueda modificar mi política en línea a través de ti?'],
#  ['¿Así que no hay forma de que pueda modificar mi política en línea a través de ti?',
#   'No, tendrás que llamar a tu corredor ¿quieres el número de teléfono?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi política.'],
#  ['Tengo una pregunta sobre mi política.', 'seguro'],
#  ['seguro', 'Necesito saber cuánto estoy asegurado para'],
#  ['Necesito saber cuánto estoy asegurado para', '¿qué plan?'],
#  ['¿qué plan?', 'Mi seguro de coche.'],
#  ['Mi seguro de coche.', 'acount number?\\'],
#  ['Hola, ¿en qué puedo ayudarle?', 'ayúdame a revisar mi póliza de seguro'],
#  ['ayúdame a revisar mi póliza de seguro', '¿Qué quieres saber?'],
#  ['¿Qué quieres saber?', '¿Qué cubre mi seguro?'],
#  ['¿Qué cubre mi seguro?', '¿Cuál es su número de póliza?'],
#  ['¿Cuál es su número de póliza?', '343454'],
#  ['343454',
#   'Su política actual cubre los daños causados por el agua, el fuego y los actos de Dios'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Necesito información de seguro'],
#  ['Necesito información de seguro',
#   'Puedo ayudar con la información del seguro.'],
#  ['Puedo ayudar con la información del seguro.',
#   'Bien, ¿cuál es mi prima de seguro médico?'],
#  ['Bien, ¿cuál es mi prima de seguro médico?',
#   'Lamento informarle en este momento que no tiene un plan de seguro médico.'],
#  ['Lamento informarle en este momento que no tiene un plan de seguro médico.',
#   'Qué. Acabo de perder mi pierna en un accidente de ciclomotor.'],
#  ['Qué. Acabo de perder mi pierna en un accidente de ciclomotor.',
#   'Lamento oír eso y desafortunadamente no tiene seguro médico para ayudar a cubrir sus gastos.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Me gustaría saber cuánto estoy asegurado para'],
#  ['Me gustaría saber cuánto estoy asegurado para',
#   '¿Podría especificar qué plan de seguro?'],
#  ['¿Podría especificar qué plan de seguro?', 'Mi seguro de vida'],
#  ['Mi seguro de vida', 'seguro de vida está cubierto por 1 millón al año.'],
#  ['seguro de vida está cubierto por 1 millón al año.',
#   '¿Es ese término o seguro de vida completo?'],
#  ['¿Es ese término o seguro de vida completo?', 'durante un año.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Estoy interesado en cambiar los términos de mi póliza de seguro de vida.'],
#  ['Estoy interesado en cambiar los términos de mi póliza de seguro de vida.',
#   'usted tiene que hacer una cita'],
#  ['usted tiene que hacer una cita', 'Ok, ¿tienes tiempo disponible mañana?'],
#  ['Ok, ¿tienes tiempo disponible mañana?', 'claro, ¿quieres que lo programe?'],
#  ['claro, ¿quieres que lo programe?', 'Sí.'],
#  ['Sí.', '¿Algo más?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo algunas preguntas sobre mi póliza de seguro'],
#  ['Tengo algunas preguntas sobre mi póliza de seguro',
#   'Sí, puedo ayudar lo mejor que pueda.'],
#  ['Sí, puedo ayudar lo mejor que pueda.',
#   'Primero te daré mi número de póliza y luego puedes obtener mi información 568768866'],
#  ['Primero te daré mi número de póliza y luego puedes obtener mi información 568768866',
#   'Bien, bien hecho.'],
#  ['Bien, bien hecho.', '¿Cómo cambiaría los términos de mi seguro de vida?'],
#  ['¿Cómo cambiaría los términos de mi seguro de vida?',
#   'Usted tendrá que hacer una cita con su corredor de seguros.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Hola quiero información sobre mi seguro'],
#  ['Hola quiero información sobre mi seguro',
#   'Claro que puedo ayudarte con eso, ¿qué compañía de seguros tienes?'],
#  ['Claro que puedo ayudarte con eso, ¿qué compañía de seguros tienes?',
#   'La póliza de seguro no es #1264616 ¿puedes sacar esa información por mí?'],
#  ['La póliza de seguro no es #1264616 ¿puedes sacar esa información por mí?',
#   'Sí, dame un segundo.'],
#  ['Sí, dame un segundo.', 'Bien'],
#  ['Bien',
#   'Parece que no tienes seguro en este momento, acabas de empezar tu trabajo y no entra en acción durante 6 meses'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Hola, tengo preguntas sobre mi seguro?'],
#  ['Hola, tengo preguntas sobre mi seguro?',
#   'Claro, ¿cuál es su número de póliza?'],
#  ['Claro, ¿cuál es su número de póliza?', '1119kj-00'],
#  ['1119kj-00', 'Ok, ¿qué te gustaría saber?'],
#  ['Ok, ¿qué te gustaría saber?', '¿Tengo cobertura sísmica?'],
#  ['¿Tengo cobertura sísmica?',
#   'Sí, pero no cobertura de daños causados por el agua.'],
#  ['Sí, pero no cobertura de daños causados por el agua.',
#   'Ok, ¿cuánto me costará añadir daño de agua a mi póliza?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Me gustaría encontrar información sobre mi política'],
#  ['Me gustaría encontrar información sobre mi política',
#   'Claro, ¿cómo puedo ayudar'],
#  ['Claro, ¿cómo puedo ayudar',
#   '¿Podría decirme si mi póliza actual cubre los daños causados por el agua?'],
#  ['¿Podría decirme si mi póliza actual cubre los daños causados por el agua?',
#   'Desafortunadamente su política actual no cubre los daños causados por el agua'],
#  ['Desafortunadamente su política actual no cubre los daños causados por el agua',
#   'Muy bien, ¿hay alguna manera de añadir eso a mi póliza?'],
#  ['Muy bien, ¿hay alguna manera de añadir eso a mi póliza?',
#   'Sí, pero sólo para hacerle saber esto puede tener un impacto en sus primas'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito información sobre cómo cambiar mi póliza de seguro de vida.'],
#  ['Necesito información sobre cómo cambiar mi póliza de seguro de vida.',
#   '¡absolutamente! ¿Qué información está buscando cambiar?'],
#  ['¡absolutamente! ¿Qué información está buscando cambiar?',
#   '¿Puede decirme cómo puedo cambiar los términos de mi póliza de seguro de vida?'],
#  ['¿Puede decirme cómo puedo cambiar los términos de mi póliza de seguro de vida?',
#   'Con el fin de cambiar sus primas de pólizas de seguro de vida tendrá que hablar con su corredor de seguros. Recomiendo hacer una cita con ellos.'],
#  ['Con el fin de cambiar sus primas de pólizas de seguro de vida tendrá que hablar con su corredor de seguros. Recomiendo hacer una cita con ellos.',
#   '¿Cómo hago eso?'],
#  ['¿Cómo hago eso?', 'Usted tendrá que llamar a su corredor al 565-7852.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'eh'],
#  ['eh', '¿En qué puedo ayudarle?'],
#  ['¿En qué puedo ayudarle?', '¿Puedo preguntarte?'],
#  ['¿Puedo preguntarte?', 'Siento no entenderlo.'],
#  ['Siento no entenderlo.', '¿Cuánto estás asegurado?'],
#  ['¿Cuánto estás asegurado?',
#   'Puedo ayudarle, por favor ingrese su número de póliza.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Cuál es mi actualización del seguro médico?'],
#  ['¿Cuál es mi actualización del seguro médico?', 'Dame tu número de póliza'],
#  ['Dame tu número de póliza', '364736438'],
#  ['364736438', 'Actualmente no tiene un plan con nosotros'],
#  ['Actualmente no tiene un plan con nosotros',
#   'Creo que todavía tengo mi prima'],
#  ['Creo que todavía tengo mi prima', 'Su cuenta expiró hace 2 meses'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola, tengo una pregunta sobre mi póliza de seguro.'],
#  ['Hola, tengo una pregunta sobre mi póliza de seguro.',
#   '¿Qué quieres saber?'],
#  ['¿Qué quieres saber?', '¿Cuánto cuesta mi prima?'],
#  ['¿Cuánto cuesta mi prima?', '$300.'],
#  ['$300.', '¿Hay otros planes que sean más baratos?'],
#  ['¿Hay otros planes que sean más baratos?',
#   'Sí, hay uno disponible por $200.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Necesito ayuda rápida hoy.'],
#  ['Necesito ayuda rápida hoy.',
#   'Ciertamente, ¿cómo puedo ayudarle con su póliza de seguro'],
#  ['Ciertamente, ¿cómo puedo ayudarle con su póliza de seguro',
#   'Tengo una pregunta sobre mi seguro. ¿Qué cubre mi póliza?'],
#  ['Tengo una pregunta sobre mi seguro. ¿Qué cubre mi póliza?',
#   'Déjame comprobarlo por ti. ¿Cuál es su número de póliza'],
#  ['Déjame comprobarlo por ti. ¿Cuál es su número de póliza',
#   '¿Dónde puedo encontrar eso?'],
#  ['¿Dónde puedo encontrar eso?', 'Sobre su política, por supuesto'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Me gustaría saber cómo puedo cambiar los términos de mi póliza de seguro de vida'],
#  ['Me gustaría saber cómo puedo cambiar los términos de mi póliza de seguro de vida',
#   '¿Me permite el número de póliza, por favor?'],
#  ['¿Me permite el número de póliza, por favor?', '453252345235'],
#  ['453252345235', 'Gracias. ¿Qué términos desea cambiar?'],
#  ['Gracias. ¿Qué términos desea cambiar?',
#   'Quiero cambiar la cantidad de dinero que le doy a mi hijo'],
#  ['Quiero cambiar la cantidad de dinero que le doy a mi hijo',
#   'Para ese tipo de cambio, tendrá que ponerse en contacto con su corredor de seguros. Esto no se puede hacer en línea.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo una pregunta sobre mi compañía de seguros.'],
#  ['Tengo una pregunta sobre mi compañía de seguros.',
#   'Puedo tratar de ayudarte con eso.'],
#  ['Puedo tratar de ayudarte con eso.',
#   '¿Puedes revisar mi acoount WERY235FH y decirme para qué estoy asegurado?'],
#  ['¿Puedes revisar mi acoount WERY235FH y decirme para qué estoy asegurado?',
#   'Un momento.'],
#  ['Un momento.', 'De acuerdo'],
#  ['De acuerdo',
#   'Mis registros muestran que tienes seguro de vida y seguro contra inundaciones.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Quiero saber cómo cambiar los términos de mi póliza de seguro de vida.'],
#  ['Quiero saber cómo cambiar los términos de mi póliza de seguro de vida.',
#   'Gracias por ponerse en contacto con la compañía de seguros KM. Verificaremos su solicitud en un momento'],
#  ['Gracias por ponerse en contacto con la compañía de seguros KM. Verificaremos su solicitud en un momento',
#   '¿Puedes responder a mi pregunta?'],
#  ['¿Puedes responder a mi pregunta?',
#   'Lo siento, pero tienes que hacer una cita con tu corredor de seguros'],
#  ['Lo siento, pero tienes que hacer una cita con tu corredor de seguros',
#   '¿Cómo puedo preparar una cita de este tipo?'],
#  ['¿Cómo puedo preparar una cita de este tipo?',
#   'póngase en contacto con el corredor de seguros.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola, ¿tenía alguna pregunta sobre mi política?'],
#  ['Hola, ¿tenía alguna pregunta sobre mi política?',
#   'Claro, ¿puedo tener tu número de póliza?'],
#  ['Claro, ¿puedo tener tu número de póliza?', 'Claro, 1234567890.'],
#  ['Claro, 1234567890.',
#   'Tengo tu póliza levantada ahora. ¿Cómo puedo ayudar?'],
#  ['Tengo tu póliza levantada ahora. ¿Cómo puedo ayudar?',
#   'Sí, me preguntaba si el seguro de mi dueño de casa. Tiene daños causados por el agua.'],
#  ['Sí, me preguntaba si el seguro de mi dueño de casa. Tiene daños causados por el agua.',
#   'RIght ahora, su póliza actual no cubre los daños causados por el agua.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Me gustaría preguntar por mi póliza de seguro por favor'],
#  ['Me gustaría preguntar por mi póliza de seguro por favor',
#   'Claro que adelante, por favor.'],
#  ['Claro que adelante, por favor.',
#   '¿Puedes decirme cuál es mi prima de seguro médico?'],
#  ['¿Puedes decirme cuál es mi prima de seguro médico?',
#   '¿Puedes darme tu número de póliza para que pueda buscarte eso?'],
#  ['¿Puedes darme tu número de póliza para que pueda buscarte eso?',
#   'mi número de póliza es 1234441'],
#  ['mi número de póliza es 1234441',
#   'Gracias. Su prima es de $200 al mes. Lo siento.'],
#  ['Gracias. Su prima es de $200 al mes. Lo siento.',
#   '¿Hay alguna manera de que pueda bajar eso?'],
#  ['¿Hay alguna manera de que pueda bajar eso?', 'Saqué la cuenta equivocada.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito ayuda con una pregunta de seguro, por favor'],
#  ['Necesito ayuda con una pregunta de seguro, por favor',
#   'Me encantaría ayudarte. ¿Cuál es tu pregunta?'],
#  ['Me encantaría ayudarte. ¿Cuál es tu pregunta?',
#   'Mi número de póliza es IJ847-089. ¿Puedes decirme cuánto estoy seguro?'],
#  ['Mi número de póliza es IJ847-089. ¿Puedes decirme cuánto estoy seguro?',
#   'Su política es tanto para el hogar como para el automóvil. ¿De qué quieres información?'],
#  ['Su política es tanto para el hogar como para el automóvil. ¿De qué quieres información?',
#   'Me gustaría información sobre mi seguro de automóvil. Alguien me habló y yo estoy en el hospital. Tuve que someterse a una cirugía y voy a estar en fisioterapia durante al menos 3 meses.'],
#  ['Me gustaría información sobre mi seguro de automóvil. Alguien me habló y yo estoy en el hospital. Tuve que someterse a una cirugía y voy a estar en fisioterapia durante al menos 3 meses.',
#   'Siento mucho oír eso. Estás asegurado por 100.000. Esperemos que eso cubra todo lo que necesita.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Necesito ayuda con mi seguro, por favor'],
#  ['Necesito ayuda con mi seguro, por favor', '¿En qué puedo ayudarle?'],
#  ['¿En qué puedo ayudarle?', '¿Cuánto está asegurado mi auto?'],
#  ['¿Cuánto está asegurado mi auto?',
#   '¿Cuál es el número de póliza, por favor?'],
#  ['¿Cuál es el número de póliza, por favor?', '3309743093434943486'],
#  ['3309743093434943486', 'ese vehículo está asegurado por $60,000'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo una pregunta sobre mi póliza de seguro'],
#  ['Tengo una pregunta sobre mi póliza de seguro', 'Sí, ¿qué tiene tu seguro?'],
#  ['Sí, ¿qué tiene tu seguro?',
#   '¿Cómo cambio los términos de mi póliza de seguro de vida?'],
#  ['¿Cómo cambio los términos de mi póliza de seguro de vida?',
#   'tendrá que ponerse en contacto con su corredor para que'],
#  ['tendrá que ponerse en contacto con su corredor para que',
#   '¿Quién es mi hermano otra vez? *corredor'],
#  ['¿Quién es mi hermano otra vez? *corredor', 'su corredor es AAA'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Necesita información de seguro'],
#  ['Necesita información de seguro',
#   '¿Con qué política y sartén necesita ayuda?'],
#  ['¿Con qué política y sartén necesita ayuda?', 'Política nº 25636976'],
#  ['Política nº 25636976', '*plan'],
#  ['*plan', '¿Cuánto estoy asegurado?'],
#  ['¿Cuánto estoy asegurado?',
#   'Bien, tienes seguro de hogar, vida y auto. ¿Con qué tipo de directiva necesita ayuda?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'necesito saber lo que cubre mi póliza'],
#  ['necesito saber lo que cubre mi póliza',
#   'Su política es una política básica del hogar. Usted está cubierto de daños por incendios y viento, No cubrimos daños o daños causados por el agua por terremotos'],
#  ['Su política es una política básica del hogar. Usted está cubierto de daños por incendios y viento, No cubrimos daños o daños causados por el agua por terremotos',
#   'Estás seguro'],
#  ['Estás seguro',
#   'Sí. Puedo comprobar que sí No cubrimos actos de Dios que incluyen daños causados por el agua y daños causados por desastres naturales'],
#  ['Sí. Puedo comprobar que sí No cubrimos actos de Dios que incluyen daños causados por el agua y daños causados por desastres naturales',
#   '¿qué pasa con la caída de ramas'],
#  ['¿qué pasa con la caída de ramas',
#   'La caída de ramas caería bajo actos de Dios. Usted ya ha optado por la cobertura del viento ya que está en una llanura de viento'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito información sobre mi seguro médico ¿puedes ayudarme con esto?'],
#  ['Necesito información sobre mi seguro médico ¿puedes ayudarme con esto?',
#   'Estaría más que feliz de ayudarte con eso'],
#  ['Estaría más que feliz de ayudarte con eso',
#   'Ok, me gustaría saber cuál es mi prima de seguro por favor'],
#  ['Ok, me gustaría saber cuál es mi prima de seguro por favor',
#   '¿Tiene que almacenar un sistema automatizado para extraer la información de su cuenta que parece que su cuenta está inactiva y que actualmente no tiene un plan de seguro médico'],
#  ['¿Tiene que almacenar un sistema automatizado para extraer la información de su cuenta que parece que su cuenta está inactiva y que actualmente no tiene un plan de seguro médico',
#   '¡¡Qué!! pero, ¿cómo sucedió esto? ¿Qué hago?'],
#  ['¡¡Qué!! pero, ¿cómo sucedió esto? ¿Qué hago?',
#   'No pagó su factura todo lo que necesita hacer es pagar sus facturas vencidas y reactivar su cuenta'],
#  ['Hola, ¿en qué puedo ayudarle?', 'ayúdame con mi seguro'],
#  ['ayúdame con mi seguro', '¿De qué plan de seguro estás preguntando?'],
#  ['¿De qué plan de seguro estás preguntando?', 'para mi seguro de automóvil'],
#  ['para mi seguro de automóvil', '¿Qué te gustaría saber?'],
#  ['¿Qué te gustaría saber?', '¿Cuánto estoy asegurado?'],
#  ['¿Cuánto estoy asegurado?', 'Hasta $150,000.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puede decirme si mi póliza cubre los daños causados por el agua?'],
#  ['¿Puede decirme si mi póliza cubre los daños causados por el agua?',
#   '¿tiene el número de póliza'],
#  ['¿tiene el número de póliza', '123456'],
#  ['123456', 'no ese número de póliza no cubre los daños causados por el agua'],
#  ['no ese número de póliza no cubre los daños causados por el agua',
#   '¿Puedo agregarlo a mi póliza?'],
#  ['¿Puedo agregarlo a mi póliza?', 'Sí'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola me gustaría saber cuánto estoy asegurado para mi póliza de seguro de vida #39393'],
#  ['Hola me gustaría saber cuánto estoy asegurado para mi póliza de seguro de vida #39393',
#   'Me encantaría ayudarte. Sólo para aclarar, ¿estamos revisando la política del Seguro de Vida para #39393?'],
#  ['Me encantaría ayudarte. Sólo para aclarar, ¿estamos revisando la política del Seguro de Vida para #39393?',
#   'Eso es correcto.'],
#  ['Eso es correcto.',
#   '¿Podría verificar los últimos cuatro dígitos de su número SSN o su código de negocio, por favor?'],
#  ['¿Podría verificar los últimos cuatro dígitos de su número SSN o su código de negocio, por favor?',
#   'Sí, son 0000'],
#  ['Sí, son 0000',
#   'Gracias por la información. Nuestros registros muestran que los pagos actuales de su seguro de vida oscilan entre $10,000 y $300,000.'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Puedes ayudarme sobre mi seguro?'],
#  ['¿Puedes ayudarme sobre mi seguro?',
#   'absolutamente. ¿De qué política está preguntando?'],
#  ['absolutamente. ¿De qué política está preguntando?',
#   '¿Quiero saber cuánto aseguré en mi seguro?'],
#  ['¿Quiero saber cuánto aseguré en mi seguro?',
#   '¿De qué plan estás preguntando?'],
#  ['¿De qué plan estás preguntando?', '¿Quiero saber cuánto?'],
#  ['¿Quiero saber cuánto?',
#   'Lo siento, pero para ayudarte necesito saber de qué plan de seguro quieres información. ¿Es auto, vida, propietarios, inquilinos, seguro de conducir?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo una pregunta sobre mi póliza de seguro.'],
#  ['Tengo una pregunta sobre mi póliza de seguro.', '¿Cuál es tu pregunta?'],
#  ['¿Cuál es tu pregunta?',
#   '¿Cuál es la cobertura de mi póliza de seguro de vida?'],
#  ['¿Cuál es la cobertura de mi póliza de seguro de vida?',
#   'Dependiendo de la edad de maduración, su póliza pagará entre $30,000 y $40,000.'],
#  ['Dependiendo de la edad de maduración, su póliza pagará entre $30,000 y $40,000.',
#   '¿Y cuál es mi pago mensual de prima?'],
#  ['¿Y cuál es mi pago mensual de prima?',
#   'Su pago mensual actual de prima es de $26.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puede ayudarme con mi compañía de seguros?'],
#  ['¿Puede ayudarme con mi compañía de seguros?', 'Sí'],
#  ['Sí', '¿Cuánto estoy asegurado?'],
#  ['¿Cuánto estoy asegurado?', '¿Cuál es tu cuenta #?'],
#  ['¿Cuál es tu cuenta #?', 'WERT345RT5'],
#  ['WERT345RT5', '¿Qué plan de seguro?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo una pregunta sobre mi póliza de seguro.'],
#  ['Tengo una pregunta sobre mi póliza de seguro.',
#   'seguro. Veo que tienes políticas de auto, hogar y vida con nosotros. ¿De qué política estás preguntando?'],
#  ['seguro. Veo que tienes políticas de auto, hogar y vida con nosotros. ¿De qué política estás preguntando?',
#   'Mi seguro de automóvil'],
#  ['Mi seguro de automóvil',
#   'Muy bien, ¿qué le gustaría saber sobre su política de auto?'],
#  ['Muy bien, ¿qué le gustaría saber sobre su política de auto?',
#   'Necesito saber cuánto estoy asegurado para'],
#  ['Necesito saber cuánto estoy asegurado para',
#   'Tienes $500,00 en automovilista sin seguro.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puede ayudar con una pregunta de seguro?'],
#  ['¿Puede ayudar con una pregunta de seguro?',
#   'ok, ¿cuál es su número de cuenta?'],
#  ['ok, ¿cuál es su número de cuenta?', '3'],
#  ['3', 'Ok, ¿cuál es tu pregunta?'],
#  ['Ok, ¿cuál es tu pregunta?',
#   '¿Mi póliza cubre los daños causados por el agua?'],
#  ['¿Mi póliza cubre los daños causados por el agua?',
#   'su política no cubre que'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Cuáles son mis civers de políticas actuales?'],
#  ['¿Cuáles son mis civers de políticas actuales?',
#   'Por favor, especifique su número de póliza'],
#  ['Por favor, especifique su número de póliza', '123654'],
#  ['123654', 'Levantando información ahora.'],
#  ['Levantando información ahora.', 'no estar esperando'],
#  ['no estar esperando',
#   'Su política actual cubre los daños causados por el fuego, el agua y los actos de Dios.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Necesito ayuda con mi seguro'],
#  ['Necesito ayuda con mi seguro', '¿Cómo puedo ayudarle con su seguro?'],
#  ['¿Cómo puedo ayudarle con su seguro?', 'Necesito saber mi prima de premiu'],
#  ['Necesito saber mi prima de premiu',
#   '¿Puedes darme tu apellido y los últimos cuatro dígitos de tu social?'],
#  ['¿Puedes darme tu apellido y los últimos cuatro dígitos de tu social?',
#   'Smith, 8877'],
#  ['Smith, 8877',
#   'Nuestros registros muestran que actualmente no tiene un plan de seguro médico con nuestra compañía. ¿Está seguro de que está en contacto con la empresa correcta?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre política'],
#  ['Tengo una pregunta sobre política',
#   'Muy bien, puedo ayudarte con eso. ¿Puedo tener su número de póliza?'],
#  ['Muy bien, puedo ayudarte con eso. ¿Puedo tener su número de póliza?',
#   '2134512'],
#  ['2134512', 'Un segundo... Muy bien, ¿con qué puedo ayudarte?'],
#  ['Un segundo... Muy bien, ¿con qué puedo ayudarte?',
#   'cubre los daños causados por el agua?'],
#  ['cubre los daños causados por el agua?',
#   'Desafortunadamente parece que su póliza no cubre los daños causados por el agua.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi seguro'],
#  ['Tengo una pregunta sobre mi seguro', '¿Cuál es la pregunta?'],
#  ['¿Cuál es la pregunta?',
#   '¿cómo puedo cambiar los términos de mi póliza de seguro de vida?'],
#  ['¿cómo puedo cambiar los términos de mi póliza de seguro de vida?',
#   'usted necesita llenar algunos formularios en línea'],
#  ['usted necesita llenar algunos formularios en línea',
#   '¿Puedes llenarlo para mí?'],
#  ['¿Puedes llenarlo para mí?', 'No estoy equipado para responder a eso'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo preguntas sobre mi política actual.'],
#  ['Tengo preguntas sobre mi política actual.',
#   'seguro. Puedo responder a cualquier pregunta política que pueda tener.'],
#  ['seguro. Puedo responder a cualquier pregunta política que pueda tener.',
#   '¿Mi póliza cubre los daños causados por las inundaciones?'],
#  ['¿Mi póliza cubre los daños causados por las inundaciones?',
#   '¿Cuál es su número de póliza?'],
#  ['¿Cuál es su número de póliza?', '23423874863274'],
#  ['23423874863274',
#   'Sí. Su póliza cubre los daños causados por el agua, incluido el causado por las inundaciones.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Sí, tengo una pregunta de seguro'],
#  ['Sí, tengo una pregunta de seguro',
#   'Ciertamente, puedo ayudar con las preguntas del seguro. ¿Qué te gustaría saber?'],
#  ['Ciertamente, puedo ayudar con las preguntas del seguro. ¿Qué te gustaría saber?',
#   '¿Estoy cubierto si me escagón de mi propio avión y me estrellaré contra mi propio auto?'],
#  ['¿Estoy cubierto si me escagón de mi propio avión y me estrellaré contra mi propio auto?',
#   'Déjame ver eso. Parece que no estoy equipado para responder a esa pregunta.'],
#  ['Déjame ver eso. Parece que no estoy equipado para responder a esa pregunta.',
#   'ok gracias de todos modos'],
#  ['ok gracias de todos modos',
#   'No hay problema. ¿Alguna pregunta más general con la que pueda ayudar?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Quiero información sobre mi póliza de seguro.'],
#  ['Quiero información sobre mi póliza de seguro.',
#   'Intentaré cumplir con sus peticiones.'],
#  ['Intentaré cumplir con sus peticiones.',
#   '¿Mi póliza cubre los daños causados por el secuestro de alienígenas?'],
#  ['¿Mi póliza cubre los daños causados por el secuestro de alienígenas?',
#   'Estás cubierto por eso, sí.'],
#  ['Estás cubierto por eso, sí.',
#   '¿Así que pagarás por los electrodos que me implantaron para que me saquen?'],
#  ['¿Así que pagarás por los electrodos que me implantaron para que me saquen?',
#   'Si tenemos las herramientas para confirmar esto.'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Puedes ayudarme con el seguro?'],
#  ['¿Puedes ayudarme con el seguro?', 'Sí, ¿cuál es su número de cuenta?'],
#  ['Sí, ¿cuál es su número de cuenta?', 'Mi número de póliza es 5734817'],
#  ['Mi número de póliza es 5734817', 'Tengo tu cuenta levantada'],
#  ['Tengo tu cuenta levantada',
#   'Para mi seguro de vida, ¿cuánto estoy cubierto de irght ahora?'],
#  ['Para mi seguro de vida, ¿cuánto estoy cubierto de irght ahora?',
#   '¿Esto es para su plan de automóvil o hogar?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puedo preguntar sobre la política actual?'],
#  ['¿Puedo preguntar sobre la política actual?', 'Sí'],
#  ['Sí', '¿Cuál es mi estado actual?'],
#  ['¿Cuál es mi estado actual?', 'Su estado es bueno'],
#  ['Su estado es bueno', '¿Hasta cuándo es la renovación de mi insuance?'],
#  ['¿Hasta cuándo es la renovación de mi insuance?', 'El año que viene'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puede ayudar con mi póliza de seguro, por favor?'],
#  ['¿Puede ayudar con mi póliza de seguro, por favor?',
#   '¿Con qué política puedo ayudarle hoy?'],
#  ['¿Con qué política puedo ayudarle hoy?', 'Mi número de póliza es 879538163'],
#  ['Mi número de póliza es 879538163',
#   'Bien, veo que usted tiene cobertura en el hogar que cubre el fuego y la pérdida debido a los volcanes'],
#  ['Bien, veo que usted tiene cobertura en el hogar que cubre el fuego y la pérdida debido a los volcanes',
#   '¿También cubre los daños causados por el agua?'],
#  ['¿También cubre los daños causados por el agua?',
#   'No hay daños por agua enumerados en esta política. Puedo agregarlo para ti'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Puedes decirme cuánto estoy asegurado?'],
#  ['¿Puedes decirme cuánto estoy asegurado?',
#   'Sí, First Ill necesita saber apellido y número de cuenta/'],
#  ['Sí, First Ill necesita saber apellido y número de cuenta/',
#   'Smith, 123456'],
#  ['Smith, 123456', 'Ok, ¿de qué plan de seguro estás preguntando?'],
#  ['Ok, ¿de qué plan de seguro estás preguntando?',
#   'Mi plan de seguro de vida'],
#  ['Mi plan de seguro de vida', 'Ok, Estás asegurado por $100,000.'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Puedes ayudarme con mi seguro?'],
#  ['¿Puedes ayudarme con mi seguro?', 'De hecho, puedo. ¿Qué necesitas hoy?'],
#  ['De hecho, puedo. ¿Qué necesitas hoy?',
#   '¿Cómo cambiaría los términos de mi póliza de seguro de vida?'],
#  ['¿Cómo cambiaría los términos de mi póliza de seguro de vida?',
#   'Para ello tendrá que ponerse en contacto con su corredor de seguros. ¿Desea información de contacto?'],
#  ['Para ello tendrá que ponerse en contacto con su corredor de seguros. ¿Desea información de contacto?',
#   'Sí, por favor.'],
#  ['Sí, por favor.', '¿Cuál es el nombre de su agente de seguros o corredor?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Quiero saber mi póliza de seguro.'],
#  ['Quiero saber mi póliza de seguro.',
#   'Claro, puedo ayudar con esa política.'],
#  ['Claro, puedo ayudar con esa política.',
#   '¿Mi seguro cubre los daños causados por el agua?'],
#  ['¿Mi seguro cubre los daños causados por el agua?',
#   'Según mis registros, su póliza no cubre los daños causados por el agua.'],
#  ['Según mis registros, su póliza no cubre los daños causados por el agua.',
#   'entonces, ¿qué cubre mi seguro?'],
#  ['entonces, ¿qué cubre mi seguro?', 'Incendios, robos y terremotos.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola, necesito ayuda con mi póliza de seguro.'],
#  ['Hola, necesito ayuda con mi póliza de seguro.', '¿Cómo puedo ayudar?'],
#  ['¿Cómo puedo ayudar?', '¿Cómo presento una reclamación?'],
#  ['¿Cómo presento una reclamación?',
#   'Póngase en contacto con su agente de seguros.'],
#  ['Póngase en contacto con su agente de seguros.', '¿Cuánto es mi deducible?'],
#  ['¿Cuánto es mi deducible?', 'Su deducible es de $500.'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Cuál es tu política?'],
#  ['¿Cuál es tu política?', '¿Qué tipo de política?'],
#  ['¿Qué tipo de política?', 'De la compañía.'],
#  ['De la compañía.', '¿Necesitas saber lo que cubre?'],
#  ['¿Necesitas saber lo que cubre?', 'Hay política actual Sí'],
#  ['Hay política actual Sí', 'Cubre el agua, el fuego y los actos de Dios'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Hola bienvenido a Insurance Pro Life!'],
#  ['Hola bienvenido a Insurance Pro Life!', '¿Cómo puedo ayudarte hoy?'],
#  ['¿Cómo puedo ayudarte hoy?',
#   'Quiero saber si mi seguro cubre los daños causados por el agua'],
#  ['Quiero saber si mi seguro cubre los daños causados por el agua',
#   '¿Cuál es su número de póliza?'],
#  ['¿Cuál es su número de póliza?', '1235558'],
#  ['1235558', 'Parece que no está cubierto por daños causados por el agua.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito información sobre por qué mi política cubre por qué no'],
#  ['Necesito información sobre por qué mi política cubre por qué no',
#   '¿Cuál es su número de póliza?'],
#  ['¿Cuál es su número de póliza?', 'AB8574967'],
#  ['AB8574967',
#   'Bien, parece que tu póliza cubre daños causados por el agua, daños por incendios y actos de Dios.'],
#  ['Bien, parece que tu póliza cubre daños causados por el agua, daños por incendios y actos de Dios.',
#   '¿Qué es un acto de Dios? ¿Como un tornado?'],
#  ['¿Qué es un acto de Dios? ¿Como un tornado?',
#   'Un acto de Dios es considerado un accidente fuera de tu control, como la caída de un árbol.'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Cuál es mi seguro médico?'],
#  ['¿Cuál es mi seguro médico?',
#   'siento decírtelo, pero no tienes un seguro médico'],
#  ['siento decírtelo, pero no tienes un seguro médico', 'Creo que tengo'],
#  ['Creo que tengo', 'Ya lo he comprobado, realmente no tienes'],
#  ['Ya lo he comprobado, realmente no tienes', '¿Puedes comprobarlo de nuevo?'],
#  ['¿Puedes comprobarlo de nuevo?', 'Sí, claro'],
#  ['Hola, ¿en qué puedo ayudarle? Hola',
#   'Hola, ¿puedes ayudar con mi póliza de seguro?'],
#  ['Hola, ¿puedes ayudar con mi póliza de seguro?', 'claro, ¿qué hay de eso?'],
#  ['claro, ¿qué hay de eso?',
#   'Recientemente tuvimos algunos daños por granizo. ¿Está cubierto con mi póliza actual?'],
#  ['Recientemente tuvimos algunos daños por granizo. ¿Está cubierto con mi póliza actual?',
#   'Déjame comprobarte eso, ¿en qué compañía estás?'],
#  ['Déjame comprobarte eso, ¿en qué compañía estás?',
#   'Estoy con Acme Incorporated.'],
#  ['Estoy con Acme Incorporated.', 'Ok, voy a comprobar eso para ti'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito información sobre mi póliza de seguro.'],
#  ['Necesito información sobre mi póliza de seguro.', 'bien gp por delante'],
#  ['bien gp por delante', '¿Mi póliza cubre los daños causados por el agua?'],
# ...
#   'cubre los daños causados por el agua'],
#  ['cubre los daños causados por el agua',
#   'No, su póliza no cubre los daños causados por el agua.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito saber lo que cubre mi política actual.'],
#  ['Necesito saber lo que cubre mi política actual.', 'su cuenta #?'],
#  ['su cuenta #?', '3561561651'],
#  ['3561561651', 'cubre el agua, el fuego, los actos de Dios'],
#  ['cubre el agua, el fuego, los actos de Dios',
#   'Bien, ¿un acto de Dios cubriría un tornado?'],
#  ['Bien, ¿un acto de Dios cubriría un tornado?', 'Sí'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo una cuenta de seguro contigo y necesito averiguar algo.'],
#  ['Tengo una cuenta de seguro contigo y necesito averiguar algo.',
#   '¿Qué tipo de plan tienes?'],
#  ['¿Qué tipo de plan tienes?', 'seguro de vida'],
#  ['seguro de vida', 'Hay varias opciones. ¿Sabes el nombre?'],
#  ['Hay varias opciones. ¿Sabes el nombre?',
#   'Seguro de vida de Mary. ¿Cuánto estoy asegurado?'],
#  ['Seguro de vida de Mary. ¿Cuánto estoy asegurado?',
#   '¿Fue por la cobertura de oro o plata?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Necesito ayuda con mi seguro, por favor'],
#  ['Necesito ayuda con mi seguro, por favor',
#   '¡Puedo ayudar con eso! Pero primero, ¿puedo tener su número de cuenta, por favor?'],
#  ['¡Puedo ayudar con eso! Pero primero, ¿puedo tener su número de cuenta, por favor?',
#   'Por supuesto, es 7145283'],
#  ['Por supuesto, es 7145283',
#   'Ok, he recogido tu información. ¿Qué tipo de ayuda necesitabas?'],
#  ['Ok, he recogido tu información. ¿Qué tipo de ayuda necesitabas?',
#   'Sólo quería saber lo que cubre mi póliza de hogar'],
#  ['Sólo quería saber lo que cubre mi póliza de hogar',
#   'Su póliza de seguro de hogar cubre los daños causados por el agua, el fuego y los actos de Dios.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Quiero saber cómo puedo cambiar los términos de mi póliza de seguro de vida.'],
#  ['Quiero saber cómo puedo cambiar los términos de mi póliza de seguro de vida.',
#   'No puedo darte esa información.'],
#  ['No puedo darte esa información.', '¿Por qué no?'],
#  ['¿Por qué no?',
#   'Para esa información es necesario hacer una cita con un corredor de seguros'],
#  ['Para esa información es necesario hacer una cita con un corredor de seguros',
#   'oh. Bueno, ¿cómo hago eso?'],
#  ['oh. Bueno, ¿cómo hago eso?',
#   'En el sitio web vaya a la sección de contacto y rellene el formulario de cita de solicitud'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puedes ayudarme sobre la póliza de seguro?'],
#  ['¿Puedes ayudarme sobre la póliza de seguro?',
#   '¡Claro! ¿Con qué se trata nuestra póliza de seguro con la que necesita ayuda?'],
#  ['¡Claro! ¿Con qué se trata nuestra póliza de seguro con la que necesita ayuda?',
#   'Sí. Quiero cambiar algunos términos de mi póliza de seguro de vida.'],
#  ['Sí. Quiero cambiar algunos términos de mi póliza de seguro de vida.',
#   'Podemos ayudar con eso, pero usted tiene que programar una cita con nuestro corredor de seguros.'],
#  ['Podemos ayudar con eso, pero usted tiene que programar una cita con nuestro corredor de seguros.',
#   'Bien. Gracias por la información. Fijaré una cita con su corredor mañana a las 9 a. m.'],
#  ['Bien. Gracias por la información. Fijaré una cita con su corredor mañana a las 9 a. m.',
#   'Bien, te he reservado para mañana a las 9 am.'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Puedes ayudarme con mi póliza?'],
#  ['¿Puedes ayudarme con mi póliza?', '¿Cuál es su número de póliza?'],
#  ['¿Cuál es su número de póliza?', '598623584'],
#  ['598623584', '¿Y qué le gustaría saber sobre su cobertura?'],
#  ['¿Y qué le gustaría saber sobre su cobertura?',
#   '¿Cómo puedo cambiar los términos de mi póliza de seguro de vida?'],
#  ['¿Cómo puedo cambiar los términos de mi póliza de seguro de vida?',
#   'Con el fin de cambiar los términos de su póliza de seguro de vida tendrá que hablar con un corredor de seguros'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi seguro'],
#  ['Tengo una pregunta sobre mi seguro', '¿Tiene su número de póliza?'],
#  ['¿Tiene su número de póliza?', '32546463746'],
#  ['32546463746', 'Bien, tengo tu información. ¿Qué te gustaría saber?'],
#  ['Bien, tengo tu información. ¿Qué te gustaría saber?',
#   'En mi seguro de coche, ¿mis tarifas subirán pronto?'],
#  ['En mi seguro de coche, ¿mis tarifas subirán pronto?',
#   'Sus tarifas no cambiarán hasta el final del período de política el 15 de octubre. Unos 30 días antes debe recibir notificación de cualquier cambio.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo algunas preguntas sobre mi póliza de seguro'],
#  ['Tengo algunas preguntas sobre mi póliza de seguro', '¿cómo puedo ayudar'],
#  ['¿cómo puedo ayudar',
#   'Necesito saber si mi póliza cubre los daños causados por el viento'],
#  ['Necesito saber si mi póliza cubre los daños causados por el viento',
#   'no, no lo hace'],
#  ['no, no lo hace', '¿Tiene mi número de póliza?'],
#  ['¿Tiene mi número de póliza?', 'tengo 557839020294'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Necesito ayuda, ¿puedes ayudarme?'],
#  ['Necesito ayuda, ¿puedes ayudarme?', 'seguro'],
#  ['seguro', '¿Quiero un seguro?'],
#  ['¿Quiero un seguro?', '¿Qué tipo de seguro?'],
#  ['¿Qué tipo de seguro?', 'Heath i]nsurance'],
#  ['Heath i]nsurance', 'Bien'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo un seguro questio'],
#  ['Tengo un seguro questio',
#   'Estoy diseñado para ayudar con las preguntas del seguro.'],
#  ['Estoy diseñado para ayudar con las preguntas del seguro.',
#   '¿Qué tipo de cobertura de vehículos tengo?'],
#  ['¿Qué tipo de cobertura de vehículos tengo?',
#   '¿Puedes decirme tu número de póliza?'],
#  ['¿Puedes decirme tu número de póliza?', '12345'],
#  ['12345',
#   'Tiene cobertura completa, nuestro paquete de seguro de primera línea.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola. Tengo algunas preguntas sobre mi política'],
#  ['Hola. Tengo algunas preguntas sobre mi política', 'Ok, puedo ayudar'],
#  ['Ok, puedo ayudar',
#   'Gracias ¿Mi póliza de seguro actual cubre los daños causados por el agua?'],
#  ['Gracias ¿Mi póliza de seguro actual cubre los daños causados por el agua?',
#   '¿Puedo tener su número de póliza?'],
#  ['¿Puedo tener su número de póliza?', 'El número es 009-129-12123'],
#  ['El número es 009-129-12123',
#   'Ok, su póliza no cubre los daños causados por el agua.'],
#  ['Hola, ¿en qué puedo ayudarle? eh',
#   'Tengo una pregunta sobre mi póliza de seguro médico'],
#  ['Tengo una pregunta sobre mi póliza de seguro médico', 'ok seguir adelante'],
#  ['ok seguir adelante',
#   'Deja que te dé mi número de póliza primero sólo para comer o seguro que estamos en la misma página. Es 256898045'],
#  ['Deja que te dé mi número de póliza primero sólo para comer o seguro que estamos en la misma página. Es 256898045',
#   'Bien'],
#  ['Bien', '¿Puedes ver mi prima de seguro y decirme qué es?'],
#  ['¿Puedes ver mi prima de seguro y decirme qué es?',
#   'según la comprobación, actualmente no tiene plan insu de salud'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Tengo una pregunta sobre mi política'],
#  ['Tengo una pregunta sobre mi política', 'Claro, ¿qué te gustaría saber?'],
#  ['Claro, ¿qué te gustaría saber?',
#   'Si mi póliza cubre los daños causados por el agua, ¿necesita el número de póliza?'],
#  ['Si mi póliza cubre los daños causados por el agua, ¿necesita el número de póliza?',
#   'Sí, por favor confirme su número de póliza para mí.'],
#  ['Sí, por favor confirme su número de póliza para mí.', '23215'],
#  ['23215', 'Veo que su póliza no cubre los daños causados por el agua.'],
#  ['Hola, ¿en qué puedo ayudarle?', 'Necesito ayuda con mi seguro.'],
#  ['Necesito ayuda con mi seguro.',
#   'Seguro que lo primero que necesito para empezar es su número de póliza'],
#  ['Seguro que lo primero que necesito para empezar es su número de póliza',
#   'AS7778 Quiero cambiar mi deducible.'],
#  ['AS7778 Quiero cambiar mi deducible.',
#   'Actualmente son 5000 ¿a qué quieres cambiarlo?'],
#  ['Actualmente son 5000 ¿a qué quieres cambiarlo?', '$500'],
#  ['$500', 'Bien, eso será $112 extra'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola, me gustaría obtener información en vivo sobre mi política actual'],
#  ['Hola, me gustaría obtener información en vivo sobre mi política actual',
#   'Claro, ¿qué te gustaría saber?'],
#  ['Claro, ¿qué te gustaría saber?',
#   '¿Me gustaría saber lo que cubre mi póliza?'],
#  ['¿Me gustaría saber lo que cubre mi póliza?',
#   'La política actual cubre los daños causados por el agua, el fuego y los actos de Dios.'],
#  ['La política actual cubre los daños causados por el agua, el fuego y los actos de Dios.',
#   '¿Qué constituye los actos de Dios?'],
#  ['¿Qué constituye los actos de Dios?',
#   'Cualquier cosa causada por fuerzas naturales como tornados, terremotos, huracanes, etc.'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Cuánto estoy cubierto?'],
#  ['¿Cuánto estoy cubierto?', '¿Qué plan de seguro está preguntando?'],
#  ['¿Qué plan de seguro está preguntando?', 'mina.'],
#  ['mina.', 'qué plan de seguro por favor'],
#  ['qué plan de seguro por favor', 'Salud'],
#  ['Salud', 'Bien, tienes $20,000 en seguro médico'],
#  ['Hola, ¿en qué puedo ayudarle?', '¿Es bueno con las pólizas de seguro?'],
#  ['¿Es bueno con las pólizas de seguro?',
#   'Sí, represento a su compañía de seguros.'],
#  ['Sí, represento a su compañía de seguros.',
#   'Tuve un accidente ¿sabes si el seguro cubre los daños causados por el agua a mi casa?'],
#  ['Tuve un accidente ¿sabes si el seguro cubre los daños causados por el agua a mi casa?',
#   'Por favor, proporcione más detalles de la cuenta que necesito su número de cuenta y los últimos dos dígitos de su dirección de casa'],
#  ['Por favor, proporcione más detalles de la cuenta que necesito su número de cuenta y los últimos dos dígitos de su dirección de casa',
#   'la tubería fue volada por una cuenta de tormenta es 123456'],
#  ['la tubería fue volada por una cuenta de tormenta es 123456',
#   'Bien, veo la cuenta.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'hola puedes ayudarme con mi seguro médico'],
#  ['hola puedes ayudarme con mi seguro médico', '¿Con qué necesitas ayuda?'],
#  ['¿Con qué necesitas ayuda?',
#   '¿Puedes decirme cuál es mi prima de seguro médico?'],
#  ['¿Puedes decirme cuál es mi prima de seguro médico?',
#   'Parece que actualmente no tienes un plan con nosotros.'],
#  ['Parece que actualmente no tienes un plan con nosotros.',
#   '¿No? ¿Puedes volver a comprobarlo?'],
#  ['¿No? ¿Puedes volver a comprobarlo?',
#   'Sí, parece que tu plan expiró. ¿Te gustaría renovar?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puedes ayudarme con mi póliza de seguro?'],
#  ['¿Puedes ayudarme con mi póliza de seguro?',
#   '¡Desde luego, puedo ayudarte con tu política! ¿Cuál es su número'],
#  ['¡Desde luego, puedo ayudarte con tu política! ¿Cuál es su número',
#   'El número de póliza es 34828423'],
#  ['El número de póliza es 34828423',
#   'Genial, tirando de eso ahora. ¿Qué le gustaría saber sobre su política'],
#  ['Genial, tirando de eso ahora. ¿Qué le gustaría saber sobre su política',
#   'Sólo quiero saber si mi póliza actualmente cubre los daños causados por el agua'],
#  ['Sólo quiero saber si mi póliza actualmente cubre los daños causados por el agua',
#   'Hm, no. arrepentido. Parece que su póliza no cubre los daños causados por el agua'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Tengo una pregunta sobre mi póliza de seguro. ¿Puedes ayudar?'],
#  ['Tengo una pregunta sobre mi póliza de seguro. ¿Puedes ayudar?',
#   'Sí, ¿cuál es la pregunta?'],
#  ['Sí, ¿cuál es la pregunta?', '¿Qué cubre mi póliza actual?'],
#  ['¿Qué cubre mi póliza actual?',
#   'Su política actual cubre los daños causados por el agua, el fuego y los actos de Dios'],
#  ['Su política actual cubre los daños causados por el agua, el fuego y los actos de Dios',
#   'Bien, gracias por la información.'],
#  ['Bien, gracias por la información.',
#   'De nada. ¿Qué más puedo hacer por ti?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Me gustaría tener información sobre mi seguro, por favor.'],
#  ['Me gustaría tener información sobre mi seguro, por favor.',
#   '¡hola! ¿En qué puedo ayudar?'],
#  ['¡hola! ¿En qué puedo ayudar?',
#   'Me gustaría saber cuánto estoy asegurado para'],
#  ['Me gustaría saber cuánto estoy asegurado para', 'seguro. comprobación...'],
#  ['seguro. comprobación...', 'gracias'],
#  ['gracias',
#   'Encontré varias pólizas de seguro. ¿Puede especificar qué directiva le gustaría conocer?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Hola me gustaría saber cuál es mi prima de seguro por favor?'],
#  ['Hola me gustaría saber cuál es mi prima de seguro por favor?',
#   '¿Puedo tener el nombre en la póliza?'],
#  ['¿Puedo tener el nombre en la póliza?', 'Sí, su Bill Nye'],
#  ['Sí, su Bill Nye', 'Sólo un momento mientras comprueba'],
#  ['Sólo un momento mientras comprueba', 'gracias'],
#  ['gracias',
#   'No estoy mostrando un plan de seguro con ese nombre, ¿hay otro nombre?'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puedo obtener información sobre mi seguro médico?'],
#  ['¿Puedo obtener información sobre mi seguro médico?',
#   'seguro. ¿cómo puedo ayudar?'],
#  ['seguro. ¿cómo puedo ayudar?', '¿Cuál es mi prima'],
#  ['¿Cuál es mi prima', '¿Puedo tener tu número de cuenta primero, por favor?'],
#  ['¿Puedo tener tu número de cuenta primero, por favor?', 'Es 73437111'],
#  ['Es 73437111',
#   'Lamento que su seguro se cancele actualmente debido al impago'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Me gustaría obtener información sobre mi póliza de seguro'],
#  ['Me gustaría obtener información sobre mi póliza de seguro',
#   'Seguro sobre ?'],
#  ['Seguro sobre ?',
#   'Mi póliza de seguro de hogar, por favor. Me gustaría saber si cubre los daños causados por el agua.'],
#  ['Mi póliza de seguro de hogar, por favor. Me gustaría saber si cubre los daños causados por el agua.',
#   'Su póliza de seguro no cubre los daños causados por el agua'],
#  ['Su póliza de seguro no cubre los daños causados por el agua',
#   'Eso es desafortunado. ¿Cuánto sería añadirlo?'],
#  ['Eso es desafortunado. ¿Cuánto sería añadirlo?', '$1000'],
#  ['Hola, ¿en qué puedo ayudarle?', 'ayúdame con las cosas del seguro'],
#  ['ayúdame con las cosas del seguro',
#   'Estoy diseñado para ayudarte con el seguro. ¿Con qué quieres ayuda?'],
#  ['Estoy diseñado para ayudarte con el seguro. ¿Con qué quieres ayuda?',
#   'Descubrí que no me muero y quiero cambiar los términos de mi seguro de vida'],
#  ['Descubrí que no me muero y quiero cambiar los términos de mi seguro de vida',
#   'Para cambiar los términos de su seguro, tendría que hablar con su corredor de seguros. ¿Le gustaría hacer una cita con su corredor?'],
#  ['Para cambiar los términos de su seguro, tendría que hablar con su corredor de seguros. ¿Le gustaría hacer una cita con su corredor?',
#   'Sí, configurarlo'],
#  ['Sí, configurarlo',
#   'Tu agente es Jimmy Frank. Está disponible el martes a las 2:30 p. m., ¿eso funciona para usted?'],
#  ['Hola, ¿en qué puedo ayudarle?', 'hola'],
#  ['hola', '¿Cómo puedo ayudarle con su seguro hoy?'],
#  ['¿Cómo puedo ayudarle con su seguro hoy?',
#   '¿Quiero saber si mi póliza cubre los daños causados por el agua?'],
#  ['¿Quiero saber si mi póliza cubre los daños causados por el agua?',
#   'Grande ¿Cuál es su número de política'],
#  ['Grande ¿Cuál es su número de política', 'su 91837475'],
#  ['su 91837475',
#   'Está bien, déjame comprobarlo. Parece que su póliza no cubre los daños causados por el agua'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   'Necesito información sobre mi plan de salud.'],
#  ['Necesito información sobre mi plan de salud.',
#   'Lo siento, pero actualmente no tiene un plan de seguro médico.'],
#  ['Lo siento, pero actualmente no tiene un plan de seguro médico.',
#   '¿No? ¿Es la compañía de seguros Cahill?'],
#  ['¿No? ¿Es la compañía de seguros Cahill?',
#   'Su seguro fue cancelado por su empleador el 25 de abril.'],
#  ['Su seguro fue cancelado por su empleador el 25 de abril.',
#   '¿Qué? ¿por qué?'],
#  ['¿Qué? ¿por qué?',
#   'No sé por qué su empleador canceló su seguro médico. Es posible que desee ponerse en contacto con su empleador.'],
#  ['Hola, ¿en qué puedo ayudarle?',
#   '¿Puedes conseguirme el número de teléfono de dominó?'],
#  ...]

# %%
## Guardando los pares que se extrajeron del dataset Dailyd y Metalw

# %%
def guardarPares(archivo, pares):
    
    with open(archivo, 'w' , encoding='utf-8') as fichero:
        
        for linea in pares:
            fichero.write(linea[0]+'\t'+linea[1]+'\n')

## en pares_conversaciones se guardar todos los pares de conversaciones de las 2 dataset
guardarPares(os.path.join("./DAILYD_METALW", "Dailyd_Metalw.txt"), pares_conversaciones)
